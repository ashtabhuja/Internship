# %% [markdown]
# # Avocado Price Analysis

# %% [markdown]
# # The table below represents weekly 2018 retail scan data for National retail volume (units) and price.
# The data set can be used to find the average price of avocado depend on the type
# The dataset contain 13 input variable and one output variable as type

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("C:\\Users\\ASHTABHUJA\\Downloads\\avocado.csv")
data
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
data.head(5)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
data.shape
# Out:
# (18249, 14)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# Since unnanmed column not adding any value to our study hence we are deleting this column

# %%
data.drop('Unnamed: 0',inplace=True,axis=1)

# %%
data
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
data.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# There is no null values is present in the dataset

# %%
sns.heatmap(data.isnull(),cmap='Blues')
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %% [markdown]
# From the above summary we can observe some points:
#
# 1.For the 4225 and smallbags,TotalBags shows left side skewness because mean is less than median
#
# 2. The TotalVolumne,LargeBags,XlargeBags shows righside skewness because mean is greater than median
#
# 3. AveragePrice,TotalVolumne,4046,4225,4770,TotalBags,SmallBags,LargeBags,XlargeBags indicates may be there is presence of outliers since there is sudden increase in value 75% and max value we can confirm the presence of outliers by box plot method

# %% [markdown]
# # EDA

# %%
sns.countplot(data=data,x='type')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# The count for the type of avocado is nearly same for both varieites

# %%
sns.barplot(data=data,x='year',y='AveragePrice')
plt.show()

# %% [markdown]
# The average price of avocado is highest in the year 2017 then 2015,2018 and least in 2016

# %%
sns.barplot(x='type',y='AveragePrice',data=data)
# Out:
# <Axes: xlabel='type', ylabel='AveragePrice'>

# %% [markdown]
# The average price for Organic variety is high compared to the average price of avocado for conventional variety

# %%
sns.scatterplot(x='AveragePrice',y='year',data=data)
# Out:
# <Axes: xlabel='AveragePrice', ylabel='year'>

# %% [markdown]
# The average price of avocado is highest in 2017 year followed by 2016 year and least in 2018 year

# %%
sns.scatterplot(x='type',y='AveragePrice',data=data)
# Out:
# <Axes: xlabel='type', ylabel='AveragePrice'>

# %% [markdown]
# Price for the organice type is highest compared to the conventional type

# %%
sns.lmplot(x='Total Volume',y='4046',data=data)

# %% [markdown]
# Total volume and the 4046 shows the positive linear relation

# %%
sns.lmplot(x='Small Bags',y='Total Bags',data=data)

# %%
sns.lmplot(x='Total Bags',y='AveragePrice',data=data)

# %% [markdown]
# 1. Small bags and Total Bags shows the positive linear relation with each other
#
# 2. TotalBags and AveragePrice shows negative linear relation with each other

# %%
sns.scatterplot(x='Total Volume',y='year',data=data)
# Out:
# <Axes: xlabel='Total Volume', ylabel='year'>

# %%
sns.scatterplot(y="Large Bags",x='year',data=data)
# Out:
# <Axes: xlabel='year', ylabel='Large Bags'>

# %% [markdown]
# In the 2018 year count of Large Bags is highest followed by 2017,2016 and least for 2015

# %%
sns.regplot(x='Small Bags',y='Total Bags',data=data)
# Out:
# <Axes: xlabel='Small Bags', ylabel='Total Bags'>

# %%
sns.lmplot(x='Small Bags',y='AveragePrice',data=data)

# %% [markdown]
# 1. Small bags and TotalBags shows positive relation with eachother
#
# 2. SmallBags and AVerage price shows negative relation with eachother

# %%
data.hist(figsize=(15,15),layout=(4,4),bins=30,grid=False)
# Out:
# array([[<Axes: title={'center': 'AveragePrice'}>,
#         <Axes: title={'center': 'Total Volume'}>,
#         <Axes: title={'center': '4046'}>,
#         <Axes: title={'center': '4225'}>],
#        [<Axes: title={'center': '4770'}>,
#         <Axes: title={'center': 'Total Bags'}>,
#         <Axes: title={'center': 'Small Bags'}>,
#         <Axes: title={'center': 'Large Bags'}>],
#        [<Axes: title={'center': 'XLarge Bags'}>,
#         <Axes: title={'center': 'year'}>, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
data.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# dtype: float64

# %% [markdown]
# As we can see there skewness present in our dataset so we are removing the skewness using np.cbrt method to remove skewness

# %%
data['XLarge Bags']=np.cbrt(data['XLarge Bags'])
data['Total Volume']=np.cbrt(data['Total Volume'])
data['4225']=np.cbrt(data['4225'])
data['4046']=np.cbrt(data['4046'])
data['4770']=np.cbrt(data['4770'])
data['Total Bags']=np.cbrt(data['Total Bags'])
data['Small Bags']=np.cbrt(data['Small Bags'])
data['Large Bags']=np.cbrt(data['Large Bags'])

# %%
data.skew()
# Out:
# AveragePrice    0.580303
# Total Volume    2.236143
# 4046            2.277861
# 4225            2.130378
# 4770            2.316048
# Total Bags      2.302176
# Small Bags      2.217682
# Large Bags      2.186514
# XLarge Bags     2.842255
# year            0.215339
# dtype: float64

# %%
data.hist(figsize=(15,15),layout=(4,4),bins=30,grid=False)
# Out:
# array([[<Axes: title={'center': 'AveragePrice'}>,
#         <Axes: title={'center': 'Total Volume'}>,
#         <Axes: title={'center': '4046'}>,
#         <Axes: title={'center': '4225'}>],
#        [<Axes: title={'center': '4770'}>,
#         <Axes: title={'center': 'Total Bags'}>,
#         <Axes: title={'center': 'Small Bags'}>,
#         <Axes: title={'center': 'Large Bags'}>],
#        [<Axes: title={'center': 'XLarge Bags'}>,
#         <Axes: title={'center': 'year'}>, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# We have removed skewness from our data

# %% [markdown]
# Outlier detection

# %%
data.plot(kind='box',subplots=True,layout=(4,5),figsize=(10,15))
# Out:
# AveragePrice       Axes(0.125,0.712609;0.133621x0.167391)
# Total Volume    Axes(0.285345,0.712609;0.133621x0.167391)
# 4046             Axes(0.44569,0.712609;0.133621x0.167391)
# 4225            Axes(0.606034,0.712609;0.133621x0.167391)
# 4770            Axes(0.766379,0.712609;0.133621x0.167391)
# Total Bags         Axes(0.125,0.511739;0.133621x0.167391)
# Small Bags      Axes(0.285345,0.511739;0.133621x0.167391)
# Large Bags       Axes(0.44569,0.511739;0.133621x0.167391)
# XLarge Bags     Axes(0.606034,0.511739;0.133621x0.167391)
# year            Axes(0.766379,0.511739;0.133621x0.167391)
# dtype: object

# %% [markdown]
# As we can except year all columns have outliers se for removing outlier we use zscore method which remove the outliers from our dataset

# %%
sns.pairplot(data=data,palette='Dark2')

# %% [markdown]
# From the above plot we can see that the-
#
# 1.Small bags and Total Bags has positive relation
#
# 2.Average Price and 4046 has negative relation
#
# 3. Average Price and Large Bags has begative relation
#
# 3. For 2018 largebas count is hightes followed by 2017,2016 and least for 2015
#
# 4. For type 1 average price is more compared to type 0
#
# 5. For type 0 count of LargeBags is more compared to type 1

# %% [markdown]
# For converting object data into int we use Labelencoder method

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lencode=LabelEncoder()

# %%
data['type']=lencode.fit_transform(data['type'])
data['region']=lencode.fit_transform(data['region'])
data
# Out:
#              Date  AveragePrice  Total Volume       4046       4225      4770  \
# 0      2015-12-27          1.33     40.049235  10.120997  37.903460  3.638275
# 1      2015-12-20          1.35     38.001150   8.768933  35.473513  3.878204
# 2      2015-12-13          0.93     49.079175   9.262632  47.790416  5.072283
# 3      2015-12-06          1.08     42.906983  10.421946  41.597133  4.171309
# 4      2015-11-29          1.28     37.093893   9.800999  35.260208  4.231732
# ...           ...           ...           ...        ...        ...       ...
# 18244  2018-02-04          1.63     25.750488  12.697058  11.520945  0.000000
# 18245  2018-01-28          1.71     24.037003  10.602029  15.083241  0.000000
# 18246  2018-01-21          1.87     23.966829  10.602681  13.486113  8.995636
# 18247  2018-01-14          1.93     25.305697  11.517001  14.392048  8.991803
# 18248  2018-01-07          1.62     25.957317  14.251854  13.306579  6.077964
#
# ...

# %% [markdown]
# Sincde the date and XLarge bags are not adding any value into our calculation hence we are removing these two columns

# %%
data.drop('Date',axis=1,inplace=True)
data.drop('XLarge Bags',axis=1,inplace=True)

# %%
from scipy.stats import zscore
dfs=np.abs(zscore(data))
print(np.where(dfs>3))
# Out:
# (array([  313,   326,   327, ..., 17304, 17402, 17428], dtype=int64), array([4, 4, 4, ..., 0, 0, 0], dtype=int64))

# %%
dfn=data[(dfs<3).all(axis=1)]
dfn
# Out:
#        AveragePrice  Total Volume       4046       4225      4770  Total Bags  \
# 0              1.33     40.049235  10.120997  37.903460  3.638275   20.564634
# 1              1.35     38.001150   8.768933  35.473513  3.878204   21.183249
# 2              0.93     49.079175   9.262632  47.790416  5.072283   20.120399
# 3              1.08     42.906983  10.421946  41.597133  4.171309   17.978534
# 4              1.28     37.093893   9.800999  35.260208  4.231732   18.355039
# ...             ...           ...        ...        ...       ...         ...
# 18244          1.63     25.750488  12.697058  11.520945  0.000000   23.810234
# 18245          1.71     24.037003  10.602029  15.083241  0.000000   21.002902
# 18246          1.87     23.966829  10.602681  13.486113  8.995636   21.100134
# 18247          1.93     25.305697  11.517001  14.392048  8.991803   22.219254
# 18248          1.62     25.957317  14.251854  13.306579  6.077964   22.903280
#
# ...

# %%
data.shape
# Out:
# (18249, 11)

# %%
dfn.shape
# Out:
# (17412, 11)

# %%
dfn.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.520980 -0.531452 -0.417125 -0.442593
# Total Volume     -0.520980      1.000000  0.896706  0.935837  0.778482
# 4046             -0.531452      0.896706  1.000000  0.726228  0.687354
# 4225             -0.417125      0.935837  0.726228  1.000000  0.760751
# 4770             -0.442593      0.778482  0.687354  0.760751  1.000000
# Total Bags       -0.495301      0.951152  0.824012  0.853557  0.701275
# Small Bags       -0.445209      0.935992  0.806949  0.849856  0.710228
# Large Bags       -0.444291      0.706575  0.645508  0.596484  0.455169
# type              0.607749     -0.730051 -0.659654 -0.695653 -0.650162
# year              0.087932      0.058505  0.006720 -0.004303 -0.078209
# region            0.003724      0.062043  0.142083  0.012668 -0.038521
#
#               Total Bags  Small Bags  Large Bags      type      year    region
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(dfn.corr(),cmap='cool_r',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# 1. Total bags and small bags has positive correlation with each other
#
# 2.Total volumne and 4046 has positive correlation with each other
#
# 3. Type and LargeBags has negative correlation with each other
#
# 3. Type and year has negative correlation with each other
#
# 4. year adding negative value to region

# %%
x=dfn.drop('type',axis=1)
y=dfn['type']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0         -0.211606     -0.338992 -0.715504  0.105857 -0.526807   -0.645105
# 1         -0.159590     -0.396209 -0.763946  0.015574 -0.507886   -0.618139
# 2         -1.251927     -0.086726 -0.746258  0.473201 -0.413723   -0.664470
# 3         -0.861807     -0.259156 -0.704722  0.243093 -0.484772   -0.757838
# 4         -0.341646     -0.421555 -0.726969  0.007649 -0.480007   -0.741425
# ...             ...           ...       ...       ...       ...         ...
# 17407      0.568635     -0.738451 -0.623208 -0.874369 -0.813715   -0.503625
# 17408      0.776700     -0.786320 -0.698270 -0.742014 -0.813715   -0.626001
# 17409      1.192828     -0.788281 -0.698246 -0.801354 -0.104334   -0.621762
# 17410      1.348877     -0.750877 -0.665488 -0.767695 -0.104636   -0.572978
# 17411      0.542627     -0.732673 -0.567502 -0.808025 -0.334417   -0.543160
#
#        Small Bags  Large Bags      year    region
# ...

# %% [markdown]
# # Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Feature']=x.columns

vif
# Out:
#    VIF values       Feature
# 0    1.616273  AveragePrice
# 1  188.791942  Total Volume
# 2   22.399882          4046
# 3   38.272131          4225
# 4    2.814245          4770
# 5  105.073416    Total Bags
# 6   59.453551    Small Bags
# 7    8.092259    Large Bags
# 8    1.308711          year
# 9    1.094230        region

# %%
x.drop('Total Volume',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Feature']=x.columns

vif
# Out:
#    VIF values       Feature
# 0    1.558625  AveragePrice
# 1    3.909738          4046
# 2    4.973248          4225
# 3    2.790626          4770
# 4   90.785950    Total Bags
# 5   59.140137    Small Bags
# 6    8.085797    Large Bags
# 7    1.308703          year
# 8    1.071600        region

# %%
x.drop('Total Bags',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Feature']=x.columns

vif
# Out:
#    VIF values       Feature
# 0    1.814144  AveragePrice
# 1    3.850472          4046
# 2    5.202060          4225
# 3    2.799236          4770
# 4    5.870153    Small Bags
# 5    2.066679    Large Bags
# 6    2.714013          type
# 7    1.297732          year

# %% [markdown]
# Since Total Bags, small bags and Total volume are multicollinear with each other hence we are dropping these two values

# %%
x.drop('Small Bags',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Feature']=x.columns

vif
# Out:
#    VIF values       Feature
# 0    1.496333  AveragePrice
# 1    3.087700          4046
# 2    3.173233          4225
# 3    2.769449          4770
# 4    2.049604    Large Bags
# 5    1.101794          year
# 6    1.071232        region

# %%
y.value_counts()
# Out:
# 1    8992
# 0    8420
# Name: type, dtype: int64

# %%
# !pip install imblearn
from imblearn.over_sampling import SMOTE
smt=SMOTE()
x1,y1=smt.fit_resample(x,y)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
y1.value_counts()
# Out:
# 0    8992
# 1    8992
# Name: type, dtype: int64

# %% [markdown]
# # Modelling

# %% [markdown]
# Since our target value is in categorical in nature we choose classification method for modelling

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.30,random_state=i)
    RF=RandomForestClassifier()
    RF.fit(x_train,y_train)
    rfpred=RF.predict(x_test)
    acc=accuracy_score(y_test,rfpred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is',maxAccu,'at Random State',maxRS)
# Out:
# Best accuracy is 0.9988880652335063 at Random State 52

# %%
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
dtpred=dt.predict(x_test)
print(accuracy_score(y_test,dtpred))
print(confusion_matrix(y_test,dtpred))
print(classification_report(y_test,dtpred))
# Out:
# 0.9920311341734618
# [[2649   16]
#  [  27 2704]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      2665
#            1       0.99      0.99      0.99      2731
#
#     accuracy                           0.99      5396
#    macro avg       0.99      0.99      0.99      5396
# weighted avg       0.99      0.99      0.99      5396

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
lrpred=lr.predict(x_test)
print(accuracy_score(y_test,lrpred))
print(classification_report(y_test,lrpred))
print(confusion_matrix(y_test,lrpred))
# Out:
# 0.9453298739807264
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94      2665
#            1       0.95      0.95      0.95      2731
#
#     accuracy                           0.95      5396
#    macro avg       0.95      0.95      0.95      5396
# weighted avg       0.95      0.95      0.95      5396
#
# [[2517  148]
#  [ 147 2584]]

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
knnpred=knn.predict(x_test)
print(accuracy_score(y_test,knnpred))
print(confusion_matrix(y_test,knnpred))
print(classification_report(y_test,knnpred))
# Out:
# 0.9979614529280949
# [[2662    3]
#  [   8 2723]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2665
#            1       1.00      1.00      1.00      2731
#
#     accuracy                           1.00      5396
#    macro avg       1.00      1.00      1.00      5396
# weighted avg       1.00      1.00      1.00      5396

# %%
svc=SVC()
svc.fit(x_train,y_train)
svcpred=svc.predict(x_test)
print(accuracy_score(y_test,svcpred))
print(classification_report(y_test,svcpred))
print(confusion_matrix(y_test,svcpred))
# Out:
# 0.984988880652335
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      2665
#            1       0.99      0.98      0.99      2731
#
#     accuracy                           0.98      5396
#    macro avg       0.98      0.99      0.98      5396
# weighted avg       0.99      0.98      0.98      5396
#
# [[2635   30]
#  [  51 2680]]

# %%
ET=ExtraTreesClassifier()
ET.fit(x_train,y_train)
etpred=ET.predict(x_test)
print(accuracy_score(y_test,etpred))
print(confusion_matrix(y_test,etpred))
print(classification_report(y_test,etpred))
# Out:
# 0.998702742772424
# [[2664    1]
#  [   6 2725]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2665
#            1       1.00      1.00      1.00      2731
#
#     accuracy                           1.00      5396
#    macro avg       1.00      1.00      1.00      5396
# weighted avg       1.00      1.00      1.00      5396

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
rfpred=rf.predict(x_test)
print(accuracy_score(y_test,rfpred))
print(confusion_matrix(y_test,rfpred))
print(classification_report(y_test,rfpred))
# Out:
# 0.9959229058561898
# [[2660    5]
#  [  17 2714]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      2665
#            1       1.00      0.99      1.00      2731
#
#     accuracy                           1.00      5396
#    macro avg       1.00      1.00      1.00      5396
# weighted avg       1.00      1.00      1.00      5396

# %%
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
gbpred=gb.predict(x_test)
print(accuracy_score(y_test,gbpred))
print(classification_report(y_test,gbpred))
print(confusion_matrix(y_test,gbpred))
# Out:
# 0.9925871015567087
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      2665
#            1       1.00      0.99      0.99      2731
#
#     accuracy                           0.99      5396
#    macro avg       0.99      0.99      0.99      5396
# weighted avg       0.99      0.99      0.99      5396
#
# [[2653   12]
#  [  28 2703]]

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(lr,x1,y1,cv=5)
print(score)
print(score.mean())
print(accuracy_score(y_test,lrpred)-score.mean())
# Out:
# [0.96441479 0.94662219 0.9471782  0.91326105 0.92046719]
# 0.9383886831907567
# 0.006941190789969687

# %%
score=cross_val_score(dt,x1,y1,cv=5)
print(score)
print(score.mean())
print(accuracy_score(y_test,dtpred)-score.mean())
# Out:
# [0.98582152 0.98887962 0.98359744 0.98276341 0.98581758]
# 0.9853759142382588
# 0.006655219935203016

# %%
score=cross_val_score(knn,x1,y1,cv=5)
print(score)
print(score.mean())
print(accuracy_score(y_test,knnpred)-score.mean())
# Out:
# [0.96024465 0.94606617 0.94940228 0.92716152 0.96718576]
# 0.9500120759389468
# 0.04794937698914814

# %%
score=cross_val_score(ET,x1,y1,cv=5)
print(score)
print(score.mean())
print(accuracy_score(y_test,etpred)-score.mean())
# Out:
# [0.99138171 0.98359744 0.99026967 0.98804559 0.96607341]
# 0.9838735653830918
# 0.014829177389332204

# %%
score=cross_val_score(svc,x1,y1,cv=5)
print(score)
print(score.mean())
print(accuracy_score(y_test,svcpred)-score.mean())
# Out:
# [0.98026133 0.96608285 0.97775924 0.96858493 0.95550612]
# 0.9696388938625471
# 0.01534998678978794

# %%
score=cross_val_score(rf,x1,y1,cv=5)
print(score)
print(score.mean())
print(accuracy_score(y_test,rfpred)-score.mean())
# Out:
# [0.99304976 0.99249374 0.98860161 0.99138171 0.99221357]
# 0.9915480797092375
# 0.004374826146952282

# %% [markdown]
# Since we are following classifcation so in that we consider the accuracy score and the difference between the accuracy score and score value is minimum for RandomForest hence our best model is Random Forest

# %% [markdown]
# # Hypertuning the Model

# %%
from sklearn.model_selection import GridSearchCV
parameter={'criterion':['gini','entropy'],
           'random_state':[10,50,1000],
           'max_depth':[0,10,20],
           'n_jobs':[-2,-1,1],
           'n_estimators':[50,100,200,300]}
GV=GridSearchCV(RandomForestClassifier(),parameter,cv=5)
GV.fit(x_train,y_train)
GV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'n_estimators': 300,
#  'n_jobs': -2,
#  'random_state': 1000}

# %%
Model=RandomForestClassifier(criterion='entropy',max_depth=20,n_estimators=300,n_jobs=-2,random_state=1000)
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
acc=accuracy_score(y_test,pred)
acc*100
# Out:
# 99.57375833951076

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(Model,'Avocado-Price Analysis.pkl')
# Out:
# ['Avocado-Price Analysis.pkl']

# %%
Model=joblib.load('Avocado-Price Analysis.pkl')
Predict1=Model.predict(x_test)
Predict1
# Out:
# array([1, 0, 1, ..., 0, 1, 1])

# %%
m=np.array(y_test)
M=pd.DataFrame()
M['Predicted']=Predict1
M['Original']=m
M
# Out:
#       Predicted  Original
# 0             1         1
# 1             0         0
# 2             1         1
# 3             1         1
# 4             0         0
# ...         ...       ...
# 5391          1         1
# 5392          1         1
# 5393          0         0
# 5394          1         1
# 5395          1         1
#
# [5396 rows x 2 columns]

# %% [markdown]
# Our Model is RandomForest Classifier which gives us the accuracy score 99.57%
