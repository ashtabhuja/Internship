# %% [markdown]
# # Temperature Forecast

# %% [markdown]
# This data is for the purpose of bias correction of next-day maximum and minimum air temperatures forecast of the LDAPS model operated by the Korea Meteorological Administration over Seoul, South Korea. This data consists of summer data from 2013 to 2017. The input data is largely composed of the LDAPS model's next-day forecast data, in-situ maximum and minimum temperatures of present-day, and geographic auxiliary variables. There are two outputs (i.e. next-day maximum and minimum air temperatures) in this data. Hindcast validation was conducted for the period from 2015 to 2017

# %% [markdown]
# Attribute Information:
# 1.station - used weather station number: 1 to 25
# 2.Date - Present day: yyyy-mm-dd ('2013-06-30' to '2017-08-30')
# 3.Present_Tmax - Maximum air temperature between 0 and 21 h on the present day (Â°C): 20 to 37.6
# 4.Present_Tmin - Minimum air temperature between 0 and 21 h on the present day (Â°C): 11.3 to 29.9
# 5.LDAPS_RHmin - LDAPS model forecast of next-day minimum relative humidity (%): 19.8 to 98.5
# 6.LDAPS_RHmax - LDAPS model forecast of next-day maximum relative humidity (%): 58.9 to 100
# 7.LDAPS_Tmax_lapse - LDAPS model forecast of next-day maximum air temperature applied lapse rate (Â°C): 17.6 to 38.5
# 8.LDAPS_Tmin_lapse - LDAPS model forecast of next-day minimum air temperature applied lapse rate (Â°C): 14.3 to 29.6
# 9.LDAPS_WS - LDAPS model forecast of next-day average wind speed (m/s): 2.9 to 21.9
# 10.LDAPS_LH - LDAPS model forecast of next-day average latent heat flux (W/m2): -13.6 to 213.4
# 11.LDAPS_CC1 - LDAPS model forecast of next-day 1st 6-hour split average cloud cover (0-5 h) (%): 0 to 0.97
# 12.LDAPS_CC2 - LDAPS model forecast of next-day 2nd 6-hour split average cloud cover (6-11 h) (%): 0 to 0.97
# 13.LDAPS_CC3 - LDAPS model forecast of next-day 3rd 6-hour split average cloud cover (12-17 h) (%): 0 to 0.98
# 14.LDAPS_CC4 - LDAPS model forecast of next-day 4th 6-hour split average cloud cover (18-23 h) (%): 0 to 0.97
# 15.LDAPS_PPT1 - LDAPS model forecast of next-day 1st 6-hour split average precipitation (0-5 h) (%): 0 to 23.7
# 16.LDAPS_PPT2 - LDAPS model forecast of next-day 2nd 6-hour split average precipitation (6-11 h) (%): 0 to 21.6
# 17.LDAPS_PPT3 - LDAPS model forecast of next-day 3rd 6-hour split average precipitation (12-17 h) (%): 0 to 15.8
# 18.LDAPS_PPT4 - LDAPS model forecast of next-day 4th 6-hour split average precipitation (18-23 h) (%): 0 to 16.7
# 19.lat - Latitude (Â°): 37.456 to 37.645
# 20.lon - Longitude (Â°): 126.826 to 127.135
# 21.DEM - Elevation (m): 12.4 to 212.3
# 22.Slope - Slope (Â°): 0.1 to 5.2
# 23.Solar radiation - Daily incoming solar radiation (wh/m2): 4329.5 to 5992.9
# 24.Next_Tmax - The next-day maximum air temperature (Â°C): 17.4 to 38.9
# 25.Next_Tmin - The next-day minimum air temperature (Â°C): 11.3 to 29.8T
#
# our output is Next_Tmax

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C://Users//ASHTABHUJA//Downloads//weather_prediction.csv')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  2013-06-30          28.7          21.4    58.255688
# 1         2.0  2013-06-30          31.9          21.6    52.263397
# 2         3.0  2013-06-30          31.6          23.3    48.690479
# 3         4.0  2013-06-30          32.0          23.4    58.239788
# 4         5.0  2013-06-30          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  2017-08-30          23.3          17.1    26.741310
# 7748     24.0  2017-08-30          23.3          17.7    24.040634
# 7749     25.0  2017-08-30          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %% [markdown]
# As we can see dataset has 7752 rows and 25 columns

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.head(5)
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  2013-06-30          28.7          21.4    58.255688    91.116364
# 1      2.0  2013-06-30          31.9          21.6    52.263397    90.604721
# 2      3.0  2013-06-30          31.6          23.3    48.690479    83.973587
# 3      4.0  2013-06-30          32.0          23.4    58.239788    96.483688
# 4      5.0  2013-06-30          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
df.tail(5)
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 7747     23.0  2017-08-30          23.3          17.1    26.741310
# 7748     24.0  2017-08-30          23.3          17.7    24.040634
# 7749     25.0  2017-08-30          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# ...

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicated values are present in dataset

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %% [markdown]
# As we can  see only date has object as datatype

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %% [markdown]
# Our dataset contain some null values we have to replace those null values

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.dropna(inplace=True)

# %% [markdown]
# We are drooping those null values which are there in our dataset

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# No null values are present in our dataset

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Day']=df['Date'].apply(lambda x:x.day)
df['Month']=df['Date'].apply(lambda x:x.month)
df['Year']=df['Date'].apply(lambda x:x.year)

df.head(5)
# Out:
#    station       Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0 2013-06-30          28.7          21.4    58.255688    91.116364
# 1      2.0 2013-06-30          31.9          21.6    52.263397    90.604721
# 2      3.0 2013-06-30          31.6          23.3    48.690479    83.973587
# 3      4.0 2013-06-30          32.0          23.4    58.239788    96.483688
# 4      5.0 2013-06-30          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...      lat  \
# 0         28.074101         23.006936  6.818887   69.451805  ...  37.6046
# 1         29.850689         24.035009  5.691890   51.937448  ...  37.6046
# 2         30.091292         24.565633  6.138224   20.573050  ...  37.5776
# 3         29.704629         23.326177  5.650050   65.727144  ...  37.6450
# 4         29.113934         23.486480  5.735004  107.965535  ...  37.5507
#
# ...

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7588.000000   7588.000000   7588.000000  7588.000000  7588.000000
# mean     13.014101     29.748366     23.195809    56.724969    88.360823
# std       7.217858      2.967401      2.400880    14.626559     7.199456
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.600000    45.960243    84.203724
# 50%      13.000000     29.900000     23.400000    55.023199    89.784122
# 75%      19.000000     32.000000     24.800000    67.115099    93.742725
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7588.000000       7588.000000  7588.000000  7588.000000
# mean          29.620128         23.511786     7.094097    62.492606
# std            2.943496          2.342579     2.177034    33.686158
# ...

# %% [markdown]
# 1.For LADPS_WS and LADPS_LH,DEM there is sudden increase in value between 75% quantile and max value which shows there will be presence of outliers and we can confirmed by the boxplot
#
# 2.LADPS_RHmin,LADPS_WS,LADPS_LH,DEM shows right side skewness because mean is greater than median
#
# 3.Present_Tmax,Present_Tmin shows lef side skewness because mean is less than median

# %% [markdown]
# # EDA

# %%
sns.barplot(x='Month',y='Solar radiation',data=df)
# Out:
# <Axes: xlabel='Month', ylabel='Solar radiation'>

# %% [markdown]
# Count of solar radiation is highest for 6 months followed by 7 months and least for 8 months

# %%
sns.histplot(x='Next_Tmax',data=df,color='r')
# Out:
# <Axes: xlabel='Next_Tmax', ylabel='Count'>

# %%
sns.histplot(x='Next_Tmin',data=df)
# Out:
# <Axes: xlabel='Next_Tmin', ylabel='Count'>

# %% [markdown]
# 1.Next_Tmax is highest for 25-35
#
# 2.Next_Tmin is highest for 20-25

# %%
sns.barplot(x='Month',y='Present_Tmax',data=df)
plt.title('Present Temp max vs Month',fontsize=16,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Present Temp max vs Month')

# %% [markdown]
# count of present temp max is higher for 8 months and for 6 and 7 months the count is almost same

# %%
sns.barplot(x='Month',y='Present_Tmin',data=df)
plt.title('Present temp min vs Month',fontsize=16,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Present temp min vs Month')

# %% [markdown]
# Count of present_Tmin is highest for 8 months followed by 7 and 6 months

# %%
sns.barplot(x='Month',y='Next_Tmax',data=df)
plt.title('Next month Tmax vs Month',fontsize=16,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Next month Tmax vs Month')

# %% [markdown]
# Count of Next_Tmax is highest for 8 months where as for the 6 and 7 months the countis almost same

# %%
sns.barplot(x='Month',y='Next_Tmin',data=df)
plt.title('Next month Tmin vs Month',fontsize=16,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Next month Tmin vs Month')

# %% [markdown]
# Count of Next_Tmin for 7 and 8 months almost same and for 6 months is least one

# %%
sns.lineplot(x='LDAPS_Tmin_lapse',y='Next_Tmin',data=df)
# Out:
# <Axes: xlabel='LDAPS_Tmin_lapse', ylabel='Next_Tmin'>

# %%
sns.scatterplot(x='Day',y='Next_Tmax',data=df)
# Out:
# <Axes: xlabel='Day', ylabel='Next_Tmax'>

# %% [markdown]
# Next_Tmax is highest for 10th day

# %%
sns.scatterplot(x='Day',y='Next_Tmin',data=df)
# Out:
# <Axes: xlabel='Day', ylabel='Next_Tmin'>

# %% [markdown]
# Next_Tmin is highest for the 1st day

# %%
sns.stripplot(x='Year',y='Next_Tmax',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Next_Tmax'>

# %% [markdown]
# Next_Tmax is highest for 2016 year

# %%
sns.stripplot(x='Year',y='Next_Tmin',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Next_Tmin'>

# %% [markdown]
# Next_Tmin is highest for 2014 year

# %%
sns.scatterplot(x='lat',y='DEM',data=df)
# Out:
# <Axes: xlabel='lat', ylabel='DEM'>

# %% [markdown]
# DEM is highest at latitude 37.450

# %%
sns.scatterplot(x='lon',y='DEM',data=df)
# Out:
# <Axes: xlabel='lon', ylabel='DEM'>

# %% [markdown]
# DEM highest at 127 longitude

# %%
sns.scatterplot(x='Month',y='Present_Tmax',data=df)
# Out:
# <Axes: xlabel='Month', ylabel='Present_Tmax'>

# %% [markdown]
# Present_Tmax is highest for 8 months and least for 6 months

# %%
sns.scatterplot(x='Year',y='Present_Tmin',data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Present_Tmin'>

# %%
sns.scatterplot(x='Slope',y='DEM',data=df)
# Out:
# <Axes: xlabel='Slope', ylabel='DEM'>

# %%
df.hist(figsize=(15,25),layout=(9,5),grid=False)
# Out:
# array([[<Axes: title={'center': 'station'}>,
#         <Axes: title={'center': 'Date'}>,
#         <Axes: title={'center': 'Present_Tmax'}>,
#         <Axes: title={'center': 'Present_Tmin'}>,
#         <Axes: title={'center': 'LDAPS_RHmin'}>],
#        [<Axes: title={'center': 'LDAPS_RHmax'}>,
#         <Axes: title={'center': 'LDAPS_Tmax_lapse'}>,
#         <Axes: title={'center': 'LDAPS_Tmin_lapse'}>,
#         <Axes: title={'center': 'LDAPS_WS'}>,
#         <Axes: title={'center': 'LDAPS_LH'}>],
#        [<Axes: title={'center': 'LDAPS_CC1'}>,
#         <Axes: title={'center': 'LDAPS_CC2'}>,
#         <Axes: title={'center': 'LDAPS_CC3'}>,
#         <Axes: title={'center': 'LDAPS_CC4'}>,
#         <Axes: title={'center': 'LDAPS_PPT1'}>],
#        [<Axes: title={'center': 'LDAPS_PPT2'}>,
#         <Axes: title={'center': 'LDAPS_PPT3'}>,
#         <Axes: title={'center': 'LDAPS_PPT4'}>,
#         <Axes: title={'center': 'lat'}>, <Axes: title={'center': 'lon'}>],
# ...

# %%
df.skew()
# Out:
# station            -0.004178
# Present_Tmax       -0.257069
# Present_Tmin       -0.353822
# LDAPS_RHmin         0.301396
# LDAPS_RHmax        -0.845264
# LDAPS_Tmax_lapse   -0.222349
# LDAPS_Tmin_lapse   -0.574035
# LDAPS_WS            1.553926
# LDAPS_LH            0.662971
# LDAPS_CC1           0.456716
# LDAPS_CC2           0.473929
# LDAPS_CC3           0.639649
# LDAPS_CC4           0.663815
# LDAPS_PPT1          5.305906
# LDAPS_PPT2          5.710360
# LDAPS_PPT3          6.356670
# LDAPS_PPT4          6.681256
# lat                 0.085377
# lon                -0.289048
# DEM                 1.721617
# Slope               1.559050
# Solar radiation    -0.524325
# Next_Tmax          -0.334842
# Next_Tmin          -0.393662
# Day                -0.010718
# Month              -0.174856
# Year                0.013575
# dtype: float64

# %% [markdown]
# As we can see LADPS_PPT1,LADPS_PPT2,LADPS_PPT3,LADPS_PPT4 show skewness we have to remove skewness from them

# %%
df['LDAPS_WS']=np.cbrt(df['LDAPS_WS'])
df['LDAPS_PPT1']=np.cbrt(df['LDAPS_PPT1'])
df['LDAPS_PPT2']=np.cbrt(df['LDAPS_PPT2'])
df['LDAPS_PPT3']=np.cbrt(df['LDAPS_PPT3'])
df['LDAPS_PPT4']=np.cbrt(df['LDAPS_PPT4'])
df['DEM']=np.cbrt(df['DEM'])
df['Slope']=np.cbrt(df['Slope'])
df['LDAPS_LH']=np.cbrt(df['LDAPS_LH'])
df['LDAPS_CC3']=np.cbrt(df['LDAPS_CC3'])
df['LDAPS_CC4']=np.cbrt(df['LDAPS_CC4'])

# %%
df.skew()
# Out:
# station            -0.004178
# Present_Tmax       -0.257069
# Present_Tmin       -0.353822
# LDAPS_RHmin         0.301396
# LDAPS_RHmax        -0.845264
# LDAPS_Tmax_lapse   -0.222349
# LDAPS_Tmin_lapse   -0.574035
# LDAPS_WS            0.877761
# LDAPS_LH           -0.348066
# LDAPS_CC1           0.456716
# LDAPS_CC2           0.473929
# LDAPS_CC3          -0.559701
# LDAPS_CC4          -0.458425
# LDAPS_PPT1          1.955868
# LDAPS_PPT2          2.267487
# LDAPS_PPT3          2.575795
# LDAPS_PPT4          2.837790
# lat                 0.085377
# lon                -0.289048
# DEM                 0.919265
# Slope               0.612855
# Solar radiation    -0.524325
# Next_Tmax          -0.334842
# Next_Tmin          -0.393662
# Day                -0.010718
# Month              -0.174856
# Year                0.013575
# dtype: float64

# %% [markdown]
# We have removed skewness from our data

# %%
df.plot(kind='box',subplots=True,layout=(9,5),figsize=(15,25))
# Out:
# station                Axes(0.125,0.807358;0.133621x0.0726415)
# Present_Tmax        Axes(0.285345,0.807358;0.133621x0.0726415)
# Present_Tmin         Axes(0.44569,0.807358;0.133621x0.0726415)
# LDAPS_RHmin         Axes(0.606034,0.807358;0.133621x0.0726415)
# LDAPS_RHmax         Axes(0.766379,0.807358;0.133621x0.0726415)
# LDAPS_Tmax_lapse       Axes(0.125,0.720189;0.133621x0.0726415)
# LDAPS_Tmin_lapse    Axes(0.285345,0.720189;0.133621x0.0726415)
# LDAPS_WS             Axes(0.44569,0.720189;0.133621x0.0726415)
# LDAPS_LH            Axes(0.606034,0.720189;0.133621x0.0726415)
# LDAPS_CC1           Axes(0.766379,0.720189;0.133621x0.0726415)
# LDAPS_CC2              Axes(0.125,0.633019;0.133621x0.0726415)
# LDAPS_CC3           Axes(0.285345,0.633019;0.133621x0.0726415)
# LDAPS_CC4            Axes(0.44569,0.633019;0.133621x0.0726415)
# LDAPS_PPT1          Axes(0.606034,0.633019;0.133621x0.0726415)
# LDAPS_PPT2          Axes(0.766379,0.633019;0.133621x0.0726415)
# ...

# %% [markdown]
# As we can see from box plot Next_Tmax,Next_Tmin,LADPS_PPT1,2,3 and 4 and other have outliers so we are removing outliers using zscore method

# %%
df.drop('Date',axis=1,inplace=True)

# %% [markdown]
# Dropping date columns because it is not useful for Machine learning model

# %%
df.corr()
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.113301      0.133282    -0.067846
# Present_Tmax      0.113301      1.000000      0.615208    -0.209059
# Present_Tmin      0.133282      0.615208      1.000000     0.122200
# LDAPS_RHmin      -0.067846     -0.209059      0.122200     1.000000
# LDAPS_RHmax      -0.169351     -0.306943     -0.018576     0.578358
# LDAPS_Tmax_lapse  0.069856      0.573777      0.467904    -0.569580
# LDAPS_Tmin_lapse  0.105277      0.628705      0.772061     0.085237
# LDAPS_WS          0.010024     -0.120273     -0.025399     0.272609
# LDAPS_LH         -0.133257      0.113988     -0.017402    -0.022431
# LDAPS_CC1         0.006539     -0.316333      0.084348     0.612831
# LDAPS_CC2         0.003526     -0.216976      0.090038     0.744774
# LDAPS_CC3        -0.001952     -0.119676      0.013964     0.645059
# LDAPS_CC4         0.008255     -0.119181     -0.021107     0.498869
# ...

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(),annot=True,cmap='Reds')
# Out:
# <Axes: >

# %% [markdown]
# 1.ION and DEM are positively correlated with each other
#
# 2.LADPS_WS and LADPS_LH are negatively correlated with each other
#
# 3.LADPS_CC1 and LADPS_LH are negatively correlated with each other
#
# 4.LADPS_CC1 and LADPS_CC2,LADPS_Tmin_lapse impacting negative value to our output value

# %%
from scipy.stats import zscore
df1=np.abs(zscore(df))
print(np.where(df1>3))
# Out:
# (array([  25,   25,   26, ..., 7581, 7582, 7582], dtype=int64), array([ 7, 14, 14, ...,  2,  2,  6], dtype=int64))

# %%
dfn=df[(df1<3).all(axis=1)]
dfn
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688    91.116364
# 1         2.0          31.9          21.6    52.263397    90.604721
# 2         3.0          31.6          23.3    48.690479    83.973587
# 3         4.0          32.0          23.4    58.239788    96.483688
# 4         5.0          31.4          21.9    56.174095    90.155128
# ...       ...           ...           ...          ...          ...
# 7745     21.0          23.1          17.8    24.688997    78.261383
# 7746     22.0          22.5          17.4    30.094858    83.690018
# 7747     23.0          23.3          17.1    26.741310    78.869858
# 7748     24.0          23.3          17.7    24.040634    77.294975
# 7749     25.0          23.2          17.4    22.933014    77.243744
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# ...

# %%
df.shape
# Out:
# (7588, 27)

# %%
dfn.shape
# Out:
# (6693, 27)

# %%
x=dfn.drop('Next_Tmax',axis=1)
y=dfn['Next_Tmax']

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x=pd.DataFrame(scale.fit_transform(x),columns=x.columns)
x
# Out:
#        station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0    -1.671834     -0.430594     -0.816456     0.212298     0.441324
# 1    -1.533032      0.688616     -0.729637    -0.223732     0.368198
# 2    -1.394229      0.583690      0.008321    -0.483716    -0.579545
# 3    -1.255426      0.723592      0.051731     0.211141     1.208439
# 4    -1.116623      0.513740     -0.599409     0.060830     0.303941
# ...        ...           ...           ...          ...          ...
# 6688  1.104222     -2.389213     -2.379192    -2.230188    -1.395952
# 6689  1.243024     -2.599065     -2.552829    -1.836830    -0.620074
# 6690  1.381827     -2.319262     -2.683057    -2.080851    -1.308987
# 6691  1.520630     -2.319262     -2.422601    -2.277366    -1.534074
# 6692  1.659433     -2.354238     -2.552829    -2.357962    -1.541396
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# ...

# %% [markdown]
# # VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['VIF value']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns

vif
# Out:
#     VIF value          Features
# 0    1.250427           station
# 1    2.823432      Present_Tmax
# 2    3.448440      Present_Tmin
# 3    6.077202       LDAPS_RHmin
# 4    2.332907       LDAPS_RHmax
# 5    7.055311  LDAPS_Tmax_lapse
# 6    8.756245  LDAPS_Tmin_lapse
# 7    1.277285          LDAPS_WS
# 8    1.514491          LDAPS_LH
# 9    4.807440         LDAPS_CC1
# 10   5.275062         LDAPS_CC2
# 11   3.697788         LDAPS_CC3
# 12   2.548299         LDAPS_CC4
# 13   2.655757        LDAPS_PPT1
# 14   2.176959        LDAPS_PPT2
# 15   1.543413        LDAPS_PPT3
# 16   1.560889        LDAPS_PPT4
# 17   1.335330               lat
# 18   1.187625               lon
# 19   3.872234               DEM
# 20   3.044071             Slope
# 21  38.304836   Solar radiation
# 22   5.662546         Next_Tmin
# 23  10.049846               Day
# 24  31.884699             Month
# 25   1.132596              Year

# %%
x.drop('Solar radiation',axis=1,inplace=True)

# %%
vif=pd.DataFrame()

vif['VIF value']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns

vif
# Out:
#     VIF value          Features
# 0    1.244604           station
# 1    2.752885      Present_Tmax
# 2    3.398035      Present_Tmin
# 3    5.949899       LDAPS_RHmin
# 4    2.322747       LDAPS_RHmax
# 5    6.779984  LDAPS_Tmax_lapse
# 6    8.742114  LDAPS_Tmin_lapse
# 7    1.276919          LDAPS_WS
# 8    1.513567          LDAPS_LH
# 9    4.807429         LDAPS_CC1
# 10   5.272457         LDAPS_CC2
# 11   3.688860         LDAPS_CC3
# 12   2.546944         LDAPS_CC4
# 13   2.649554        LDAPS_PPT1
# 14   2.166658        LDAPS_PPT2
# 15   1.530686        LDAPS_PPT3
# 16   1.555232        LDAPS_PPT4
# 17   1.246868               lat
# 18   1.178942               lon
# 19   3.333155               DEM
# 20   2.942077             Slope
# 21   5.626775         Next_Tmin
# 22   1.147756               Day
# 23   1.177389             Month
# 24   1.131947              Year

# %%
x.drop('LDAPS_Tmin_lapse',axis=1,inplace=True)

# %%
vif=pd.DataFrame()

vif['VIF value']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns

vif
# Out:
#     VIF value          Features
# 0    1.244216           station
# 1    2.624529      Present_Tmax
# 2    3.284236      Present_Tmin
# 3    4.738951       LDAPS_RHmin
# 4    2.285727       LDAPS_RHmax
# 5    4.357285  LDAPS_Tmax_lapse
# 6    1.272688          LDAPS_WS
# 7    1.432412          LDAPS_LH
# 8    4.685242         LDAPS_CC1
# 9    5.251596         LDAPS_CC2
# 10   3.687529         LDAPS_CC3
# 11   2.546265         LDAPS_CC4
# 12   2.626834        LDAPS_PPT1
# 13   2.164696        LDAPS_PPT2
# 14   1.530215        LDAPS_PPT3
# 15   1.551881        LDAPS_PPT4
# 16   1.241981               lat
# 17   1.176734               lon
# 18   3.209685               DEM
# 19   2.837649             Slope
# 20   4.502800         Next_Tmin
# 21   1.143220               Day
# 22   1.169874             Month
# 23   1.123579              Year

# %% [markdown]
# # SMOTE

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=15)
x_new=pca.fit_transform(x)
x_new
# Out:
# array([[ 0.12961447,  3.38617746, -1.32547085, ...,  0.74594445,
#         -0.05092251,  0.69947398],
#        [-0.66511683,  1.22040851, -0.04398455, ...,  0.85318604,
#          0.13508528,  0.6089351 ],
#        [-0.94802321,  0.06437465,  0.79715258, ...,  0.91944126,
#          0.1532788 ,  0.0884132 ],
#        ...,
#        [-3.22296784,  3.52355378,  3.60024161, ...,  0.62827544,
#          0.46352422, -0.08295221],
#        [-3.38943623,  3.16165973,  3.67255542, ...,  0.70365825,
#          0.31559503, -0.35725091],
#        [-3.26261233,  3.29435252,  4.29561889, ...,  0.91827976,
#         -0.07563511, -0.77081146]])

# %%
x1=pd.DataFrame(x_new,columns=np.arange(15))
x1
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.129614  3.386177 -1.325471 -0.193830  0.304071 -1.581385  0.715762
# 1    -0.665117  1.220409 -0.043985 -1.000748 -1.461482 -1.591947  0.346042
# 2    -0.948023  0.064375  0.797153 -0.824434 -0.991945 -2.460895 -0.321190
# 3    -0.344694  1.071529 -1.618727 -0.913933 -1.244841 -1.609869  0.768997
# 4    -0.603482  1.171907 -0.135383 -0.917950 -1.715163 -1.099252  0.456753
# ...        ...       ...       ...       ...       ...       ...       ...
# 6688 -3.140476  3.609861  3.471427 -0.855137 -0.166276 -0.677276 -1.035980
# 6689 -2.755257  3.903760  3.156866 -1.291815 -1.307117  1.050163  0.122249
# 6690 -3.222968  3.523554  3.600242 -1.781892 -0.360127  1.775886  0.622276
# 6691 -3.389436  3.161660  3.672555 -1.645720  0.138209  1.255086  0.199432
# 6692 -3.262612  3.294353  4.295619 -1.245250  0.462881 -0.055919 -0.916206
#
# ...

# %% [markdown]
# # Modelling

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso,Ridge

# %%
maxr2_score=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x1,y,random_state=i,test_size=0.30)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    lrpred=lr.predict(x_test)
    r2=r2_score(y_test,lrpred)
    if r2>maxr2_score:
        maxr2_score=r2
        maxRS=i
print('Best R2 score is',maxr2_score,'at random state',maxRS)
# Out:
# Best R2 score is 0.7607807764036156 at random state 116

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
dtpred=dtr.predict(x_test)
print('Mean absolute error',mean_absolute_error(y_test,dtpred))
print('Mean squared error',mean_squared_error(y_test,dtpred))
print('Root mean square error',np.sqrt(mean_squared_error(y_test,dtpred)))
print('R2 score',r2_score(y_test,dtpred))
# Out:
# Mean absolute error 1.3135956175298804
# Mean squared error 3.325184262948207
# Root mean square error 1.8235087778643149
# R2 score 0.6140448162111471

# %%
svr=SVR()
svr.fit(x_train,y_train)
svrpred=svr.predict(x_test)
print('Mean absolute error',mean_absolute_error(y_test,svrpred))
print('Mean squared error',mean_squared_error(y_test,svrpred))
print('Root mean square error',np.sqrt(mean_squared_error(y_test,svrpred)))
print('R2 score',r2_score(y_test,svrpred))
# Out:
# Mean absolute error 0.8602616920949705
# Mean squared error 1.3298450973729483
# Root mean square error 1.1531890987053894
# R2 score 0.8456444610644798

# %%
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
knnpred=knn.predict(x_test)
print('Mean absolute error',mean_absolute_error(y_test,knnpred))
print('Mean squared error',mean_squared_error(y_test,knnpred))
print('Root mean square error',np.sqrt(mean_squared_error(y_test,knnpred)))
print('R2 score',r2_score(y_test,knnpred))
# Out:
# Mean absolute error 0.8733366533864542
# Mean squared error 1.346034462151394
# Root mean square error 1.1601872530550377
# R2 score 0.8437653564000814

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
rfpred=rf.predict(x_test)
print('Mean absolute error',mean_absolute_error(y_test,rfpred))
print('Mean squared error',mean_squared_error(y_test,rfpred))
print('Root mean square error',np.sqrt(mean_squared_error(y_test,rfpred)))
print('R2 score',r2_score(y_test,rfpred))
# Out:
# Mean absolute error 0.9117400398406376
# Mean squared error 1.4664080637450196
# Root mean square error 1.210953369764922
# R2 score 0.8297935545832396

# %%
ET=ExtraTreesRegressor()
ET.fit(x_train,y_train)
ETpred=ET.predict(x_test)
print('Mean absolute error',mean_absolute_error(y_test,ETpred))
print('Mean squared error',mean_squared_error(y_test,ETpred))
print('Root mean square error',np.sqrt(mean_squared_error(y_test,ETpred)))
print('R2 score',r2_score(y_test,ETpred))
# Out:
# Mean absolute error 0.8568799800796811
# Mean squared error 1.2620097305776883
# Root mean square error 1.1233920644982713
# R2 score 0.853518133435236

# %%
gb=GradientBoostingRegressor()
gb.fit(x_train,y_train)
gbpred=gb.predict(x_test)
print('Mean absolute error',mean_absolute_error(y_test,gbpred))
print('Mean squared error',mean_squared_error(y_test,gbpred))
print('Root mean square error',np.sqrt(mean_squared_error(y_test,gbpred)))
print('R2 score',r2_score(y_test,gbpred))
# Out:
# Mean absolute error 1.0465964881655745
# Mean squared error 1.8239422625567239
# Root mean square error 1.350534065677991
# R2 score 0.7882944476162098

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(ET,x,y,cv=5)
print(score)
print(score.mean())
print(r2_score(y_test,ETpred)-score.mean())
# Out:
# [0.73568303 0.65137867 0.72455993 0.73742403 0.61255597]
# 0.6923203261439603
# 0.16119780729127564

# %%
score=cross_val_score(rf,x,y,cv=5)
print(score)
print(score.mean())
print(r2_score(y_test,rfpred)-score.mean())
# Out:
# [0.73478364 0.67603337 0.69289269 0.69653299 0.63083011]
# 0.6862145605775904
# 0.1435789940056491

# %%
score=cross_val_score(dtr,x,y,cv=5)
print(score)
print(score.mean())
print(r2_score(y_test,dtpred)-score.mean())
# Out:
# [0.43397906 0.31071597 0.41658598 0.48901296 0.39026599]
# 0.4081119926072387
# 0.20593282360390847

# %%
score=cross_val_score(svr,x,y,cv=5)
print(score)
print(score.mean())
print(r2_score(y_test,svrpred)-score.mean())
# Out:
# [0.74602378 0.59279603 0.73426912 0.78428538 0.59875088]
# 0.6912250379874694
# 0.1544194230770104

# %%
score=cross_val_score(knn,x,y,cv=5)
print(score)
print(score.mean())
print(r2_score(y_test,knnpred)-score.mean())
# Out:
# [0.58918737 0.38502931 0.54120302 0.6008044  0.52859854]
# 0.5289645287007738
# 0.3148008276993076

# %%
score=cross_val_score(gb,x,y,cv=5)
print(score)
print(score.mean())
print(r2_score(y_test,gbpred)-score.mean())
# Out:
# [0.76931246 0.67530607 0.70814149 0.74388719 0.64314465]
# 0.707958374691417
# 0.08033607292479283

# %% [markdown]
# # Hypertuning the Model

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
pars={'kernel':['poly','rbf','linear'],'degree':[2,3,4,5],'gamma':['scale','auto','float']}
GV=GridSearchCV(SVR(),pars,cv=5)
GV.fit(x_train,y_train)
GV.best_params_
# Out:
# {'degree': 2, 'gamma': 'auto', 'kernel': 'rbf'}

# %%
Models=SVR(kernel='rbf',gamma='auto',degree=2)
Models.fit(x_train,y_train)
pred=Models.predict(x_test)
print('Mean absolute error',mean_absolute_error(y_test,pred))
print('Mean squared error',mean_squared_error(y_test,pred))
print('R2 score',r2_score(y_test,pred))
# Out:
# Mean absolute error 0.8289273518321325
# Mean squared error 1.2255858421431947
# R2 score 0.8577458656279102

# %%
from sklearn.model_selection import GridSearchCV
par={'criterion':['mse','mae','poisson'],
     'random_state':[10,50,1000],
     'max_depth':[0,10,20],
    'n_jobs':[-2,-1,1],
    'n_estimators':[50,100,200,300]}
GV=GridSearchCV(RandomForestRegressor(),par,cv=5)
GV.fit(x_train,y_train)
GV.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_depth': 20,
#  'n_estimators': 300,
#  'n_jobs': -2,
#  'random_state': 10}

# %%
Model=RandomForestRegressor(criterion='poisson',max_depth=20,n_estimators=300,n_jobs=-2,random_state=10)
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print('Mean absolute error',mean_absolute_error(y_test,pred))
print('Mean squared error',mean_squared_error(y_test,pred))
print('R2 score',r2_score(y_test,pred))
# Out:
# Mean absolute error 0.8993599939184688
# Mean squared error 1.4289153086808057
# R2 score 0.8341453504619826

# %% [markdown]
# RandomForestRegressor is our best model because it gives 0.90 of R2 score so we are saving the RandomForestRegressor as our Final Model

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(Model,'weather_prediction.pkl')
# Out:
# ['weather_prediction.pkl']

# %%
Model=joblib.load('weather_prediction.pkl')
pred=Model.predict(x_test)
pred
# Out:
# array([33.75727778, 33.9164748 , 30.23595567, ..., 31.94753775,
#        29.26383333, 30.3750582 ])

# %%
k=np.array(y_test)
k=pd.DataFrame()
k['Predicted']=pred
k['Original']=k
k
# Out:
#       Predicted   Original
# 0     33.757278  33.757278
# 1     33.916475  33.916475
# 2     30.235956  30.235956
# 3     33.895317  33.895317
# 4     32.491953  32.491953
# ...         ...        ...
# 2003  27.362667  27.362667
# 2004  33.534792  33.534792
# 2005  31.947538  31.947538
# 2006  29.263833  29.263833
# 2007  30.375058  30.375058
#
# [2008 rows x 2 columns]
