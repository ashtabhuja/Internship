# %% [markdown]
# # Zomato API Analysis is one of the most useful analysis for foodies who want to taste the best cuisines of every part of the world which lies in their budget. This analysis is also for those who want to find the value for money restaurants in various parts of the country for the cuisines. Additionally, this analysis caters the needs of people who are striving to get the best cuisine of the country and which locality of that country serves that cuisines with maximum number of restaurants.♨️
#
# For more information on Zomato API and Zomato API key

# %% [markdown]
# # Data Storage:
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
#
# • Restaurant Name: Name of the restaurant
#
# • Country Code: Country in which restaurant is located
#
# • City: City in which restaurant is located
#
# • Address: Address of the restaurant
#
# • Locality: Location in the city
#
# • Locality Verbose: Detailed description of the locality
#
# • Longitude: Longitude coordinate of the restaurant's location
#
# • Latitude: Latitude coordinate of the restaurant's location
#
# • Cuisines: Cuisines offered by the restaurant
#
# • Average Cost for two: Cost for two people in different currencies👫
#
# • Currency: Currency of the country
#
# • Has Table booking: yes/no
#
# • Has Online delivery: yes/ no
#
# • Is delivering: yes/ no
#
# • Switch to order menu: yes/no
#
# • Price range: range of price of food
#
# • Aggregate Rating: Average rating out of 5
#
# • Rating color: depending upon the average rating color
#
# • Rating text: text on the basis of rating of rating
#
# • Votes: Number of ratings casted by people

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:\\Users\\ASHTABHUJA\\Downloads\\zomato.csv",encoding='latin1')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
print('Number of rows:',df.shape[0])
print('Number of columns:',df.shape[1])
# Out:
# Number of rows: 9551
# Number of columns: 21

# %% [markdown]
# Dataset contain 9551 rows and 21 columns

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Dataset contain no null values

# %%
df.isin(['?']).sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# There is no '?' in our dataset

# %%
df.isin([' ','NA','-']).sum().any()
# Out:
# False

# %% [markdown]
# There is no whitespace present in dataset

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# There is no null values are present in our dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %% [markdown]
# Dataset contain Restaurant name,City,Address,Locality,Locality verbose,Cuisines,Is delivering now,switch to order menu,rating color,rating text contain object as data type

# %%
category=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        category.append(i)
print('Categorical columns:',category)

numerical=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical.append(i)
print('Numerical columns:',numerical)
# Out:
# Categorical columns: ['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text']
# Numerical columns: ['Restaurant ID', 'Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
for l in df.columns:
    print(df[l].value_counts())
    print('\n')
# Out:
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: Restaurant ID, Length: 9551, dtype: int64
#
#
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
#
#
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
#
#
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# 1. Votes shows right hand side skewness since mean is greater than median
#
# 2. Country code,latitiude,longitutde,Average cost for two,Aggregate rating shows left side skewness since mean is less than median
#
# 3. There is sudden increase in value between 75% quantile and max values for the Country code,Average  cost for two,Votes which shows the presence of outliers but we can get confirmation for outliers by box plot

# %%
df.plot(kind='box',subplots=True,layout=(4,4),figsize=(15,15),color='Blue')
# Out:
# Restaurant ID              Axes(0.125,0.712609;0.168478x0.167391)
# Country Code            Axes(0.327174,0.712609;0.168478x0.167391)
# Longitude               Axes(0.529348,0.712609;0.168478x0.167391)
# Latitude                Axes(0.731522,0.712609;0.168478x0.167391)
# Average Cost for two       Axes(0.125,0.511739;0.168478x0.167391)
# Price range             Axes(0.327174,0.511739;0.168478x0.167391)
# Aggregate rating        Axes(0.529348,0.511739;0.168478x0.167391)
# Votes                   Axes(0.731522,0.511739;0.168478x0.167391)
# dtype: object

# %% [markdown]
# country code,latitude,longitude,Votes,average cost for two,price range,aggregate rating shows outliers

# %%
plt.figure(figsize=(20,15),facecolor='White')
plotnumber=1
for k in numerical:
    if plotnumber<=8:
        ay=plt.subplot(4,4,plotnumber)
        sns.distplot(df[k],color='m')
        plt.xlabel(k,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # EDA

# %%
sns.countplot(x='Has Table booking',data=df,palette='inferno')
plt.title('Has Table booking')
plt.show()

# %% [markdown]
# The count of No table booking is more than yes table booking

# %%
sns.countplot(x='Has Online delivery',data=df,palette='mako')
plt.title('Count of online delivery',fontweight='bold')
plt.show()

# %% [markdown]
# The count of No online delivery is more than yes online delivery

# %%
explode=[0.2,0,0,0]
df['Price range'].value_counts().plot(kind='pie',explode=explode,autopct='%0.2f%%')
# Out:
# <Axes: ylabel='Price range'>

# %% [markdown]
# Count of 1 price range is highest followed by 2 and 4 has the least one

# %%
sns.countplot(y='Aggregate rating',data=df,palette='inferno')
plt.title('Aggregate Rating',fontweight='bold')
plt.show()

# %% [markdown]
# Count of aggregate rating 3.0 and 3.1 is highest one and 2 has the least one

# %%
plt.hist(x='Average Cost for two',data=df,color='Red')
plt.title('Average cos for two people',fontweight='bold')
plt.show()

# %%
sns.distplot(df['Aggregate rating'],color='Blue')
plt.title('Aggregate rating',fontweight='bold')
plt.show()

# %% [markdown]
# Aggregate rating is ranging from 2 to 5

# %%
sns.distplot(df['Price range'],color='Red')
plt.title('Price range is',fontweight='bold')
plt.show()

# %% [markdown]
# Price range is distributed between the 1,2,3 and 4

# %%
sns.barplot(x='Rating text',y='Votes',hue='Rating color',data=df,palette='viridis')
plt.title('Rating on basis of color',fontweight='bold')
plt.show()

# %% [markdown]
# In rating text Excellent has the highest count and the average has the least one

# %%
sns.distplot(df['Price range'],hist=False,color='Red')
sns.distplot(df['Aggregate rating'],hist=False,color='Yellow')
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Density'>

# %%
sns.lineplot(x='Has Online delivery',y='Votes',data=df)
plt.title('Voting on basis of online order',fontweight='bold')
plt.show()

# %% [markdown]
# Lineplot shows that the yes online delivery has the highest count as compared to the No online delivery

# %%
sns.scatterplot(x='Price range',y='Votes',hue='Aggregate rating',data=df,palette='inferno')
plt.title('Price range on rating basis',fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Price range on rating basis')

# %% [markdown]
# Price range 4 has the highest count when compared to votes

# %%
sns.pairplot(data=df,palette='inferno')

# %%
df.skew()
# Out:
# Restaurant ID            0.061570
# Country Code             3.043965
# Longitude               -2.807328
# Latitude                -3.081635
# Average Cost for two    35.477915
# Price range              0.889618
# Aggregate rating        -0.954130
# Votes                    8.807637
# dtype: float64

# %% [markdown]
# Average cost for two has the skewness so we can remove the skewness using np.cbrt method

# %%
df['Average Cost for two']=np.cbrt(df['Average Cost for two'])

# %%
df['Votes']=np.cbrt(df['Votes'])

# %% [markdown]
# As we can see we have removed the skewness from the both Average cost for two and Votes

# %%
df.skew()
# Out:
# Restaurant ID           0.061570
# Country Code            3.043965
# Longitude              -2.807328
# Latitude               -3.081635
# Average Cost for two    9.626632
# Price range             0.889618
# Aggregate rating       -0.954130
# Votes                   1.204920
# dtype: float64

# %%
df['Country Code']=np.cbrt(df['Country Code'])

# %%
df.skew()
# Out:
# Restaurant ID           0.061570
# Country Code            2.923867
# Longitude              -2.807328
# Latitude               -3.081635
# Average Cost for two    9.626632
# Price range             0.889618
# Aggregate rating       -0.954130
# Votes                   1.204920
# dtype: float64

# %% [markdown]
# We have converted object data into integer

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for m in category:
    df[m]=le.fit_transform(df[m])
df.head(5)
# Out:
#    Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0        6317637             3749      5.451362    73     8685       171
# 1        6304287             3173      5.451362    73     6055       593
# 2        6300002             2897      5.451362    75     4684       308
# 3        6318506             4707      5.451362    75     8690       862
# 4        6314302             5523      5.451362    75     8689       862
#
#    Locality Verbose   Longitude   Latitude  Cuisines  ...  Currency  \
# 0               172  121.027535  14.565443       920  ...         0
# 1               601  121.014101  14.553708      1111  ...         0
# 2               314  121.056831  14.581404      1671  ...         0
# 3               875  121.056475  14.585318      1126  ...         0
# 4               875  121.057508  14.584450      1122  ...         0
#
#    Has Table booking  Has Online delivery  Is delivering now  \
# ...

# %% [markdown]
# We have drop the Switch to order menu from our dataset since it is not useful

# %%
df.drop('Switch to order menu',axis=1,inplace=True)

# %%
df.corr()
# Out:
#                       Restaurant ID  Restaurant Name  Country Code      City  \
# Restaurant ID              1.000000         0.003999      0.144792 -0.005844
# Restaurant Name            0.003999         1.000000      0.020457 -0.001399
# Country Code               0.144792         0.020457      1.000000 -0.178766
# City                      -0.005844        -0.001399     -0.178766  1.000000
# Address                    0.080615         0.000763     -0.212091 -0.019763
# Locality                   0.069511         0.004322     -0.120253  0.096444
# Locality Verbose           0.070102         0.004281     -0.117650  0.093142
# Longitude                 -0.226081        -0.001920     -0.681031  0.117391
# Latitude                  -0.052081         0.009922     -0.052376 -0.004301
# Cuisines                  -0.077664         0.051496     -0.132398  0.025764
# Average Cost for two      -0.137003         0.040538     -0.229100 -0.012940
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),cmap='plasma',annot=True,linewidths=2,linecolor='Black',fmt='0.2g')
# Out:
# <Axes: >

# %% [markdown]
# 1. Locality and Locality verbose is highly correlated with each other
#
# 2. locality verbose and longitutde is positively correlated with each other
#
# 3. Average rating and rating color is negatively correlated with each other
#
# 4. Country and city is negatively correlated with each other

# %%
drop=['Longitude','Latitude','Country Code']
df.drop(drop,axis=1,inplace=True)

# %% [markdown]
# longitude,latitude and country code dropping these column since it is not useful

# %%
df.shape
# Out:
# (9551, 17)

# %% [markdown]
# Dropping 'Aggregate rating' since its our target variable

# %%
x=df.drop('Aggregate rating',axis=1)
y=df['Aggregate rating']

# %%
y.value_counts()
# Out:
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x=pd.DataFrame(scale.fit_transform(x),columns=x.columns)
x
# Out:
#       Restaurant ID  Restaurant Name      City   Address  Locality  \
# 0         -0.310940         0.044706 -0.228533  1.614667 -1.542278
# 1         -0.312458        -0.224101 -0.228533  0.589558 -0.206201
# 2         -0.312946        -0.352904 -0.142317  0.055177 -1.108528
# 3         -0.310841         0.491783 -0.142317  1.616615  0.645470
# 4         -0.311319         0.872592 -0.142317  1.616226  0.645470
# ...             ...              ...       ...       ...       ...
# 9546      -0.356658         0.368580  2.659685  0.539277 -0.446821
# 9547      -0.357452        -1.093055  2.659685  0.553309 -0.336009
# 9548      -0.356649        -0.272635  2.659685  0.554868 -0.329677
# 9549      -0.356614        -1.465464  2.659685  0.555258 -0.329677
# 9550      -0.355330         1.673878  2.659685 -0.110867  0.037586
#
#       Locality Verbose  Cuisines  Average Cost for two  Currency  \
# 0            -1.523333 -0.135907              0.719417 -4.351046
# ...

# %% [markdown]
# # Modelling

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    RF=RandomForestRegressor()
    RF.fit(x_train,y_train)
    rfpred=RF.predict(x_test)
    acc=r2_score(y_test,rfpred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Maximum accuracy score is:',maxAccu,'at random state:',maxRS)
# Out:
# Maximum accuracy score is: 0.9894542682359556 at random state: 111

# %%
lr=LinearRegression()
svr=SVR()
rf=RandomForestRegressor()
et=ExtraTreesRegressor()
knn=KNeighborsRegressor()
dtr=DecisionTreeRegressor()
ab=AdaBoostRegressor()

models=[lr,svr,rf,et,knn,dtr,ab]

for k in models:
    k.fit(x_train,y_train)
    predict=k.predict(x_test)
    print('R2 score of:',k)
    R2_score=r2_score(y_test,predict)
    print("Accuracy score is:",R2_score)
    print('Mean absolute error:',mean_absolute_error(y_test,predict))
    print('Mean squared error:',mean_squared_error(y_test,predict))
    print('Root mean square error:',np.sqrt(mean_squared_error(y_test,predict)))
    print('_________________________________________________________________________')
# Out:
# R2 score of: LinearRegression()
# Accuracy score is: 0.6501414007255404
# Mean absolute error: 0.7294604319952934
# Mean squared error: 0.8055764851357428
# Root mean square error: 0.8975391273564305
# _________________________________________________________________________
# R2 score of: SVR()
# Accuracy score is: 0.9644910730922474
# Mean absolute error: 0.18817138010619078
# Mean squared error: 0.081762050693083
# Root mean square error: 0.2859406419050692
# _________________________________________________________________________
# R2 score of: RandomForestRegressor()
# Accuracy score is: 0.9880468894294017
# Mean absolute error: 0.11341172365666438
# Mean squared error: 0.02752296161898115
# Root mean square error: 0.1659004569583253
# _________________________________________________________________________
# R2 score of: ExtraTreesRegressor()
# Accuracy score is: 0.9875314056027378
# Mean absolute error: 0.11573900907187719
# Mean squared error: 0.028709903000697833
# ...

# %%
from sklearn.model_selection import cross_val_score
for k in models:
    print('Cross validation score is:',k)
    score=cross_val_score(k,x,y,cv=5)
    print(score)
    crossval=score.mean()
    print("Cross validation score:",crossval)
    print('Difference in score is:',abs(R2_score-crossval))
    print('____________________________________________________')
# Out:
# Cross validation score is: LinearRegression()
# [0.38392599 0.53255313 0.68167443 0.67424447 0.4027212 ]
# Cross validation score: 0.5350238460032348
# Difference in score is: 0.4472364807891607
# ____________________________________________________
# Cross validation score is: SVR()
# [0.91924379 0.946761   0.96166561 0.96600722 0.95461239]
# Cross validation score: 0.9496580007779756
# Difference in score is: 0.032602326014419925
# ____________________________________________________
# Cross validation score is: RandomForestRegressor()
# [0.9847979  0.98487376 0.98815597 0.98684029 0.98891961]
# Cross validation score: 0.9867175061834308
# Difference in score is: 0.004457179391035293
# ____________________________________________________
# Cross validation score is: ExtraTreesRegressor()
# [0.98458986 0.98454551 0.98780033 0.98680706 0.9887953 ]
# Cross validation score: 0.9865076118193489
# Difference in score is: 0.0042472850269533735
# ...

# %% [markdown]
# Since extratreeregressor gives least values difference hence we are selecting Extratreeregressor as our model
