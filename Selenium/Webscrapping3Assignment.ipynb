# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#importing required library
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By

# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
#connecting to the webdriver
driver=webdriver.Chrome()
time.sleep(2)

#connecting to the server
url='http://www.amazon.in/'
driver.get(url)
time.sleep(2)

#entering the user input
User_input=input('Enter the title of Product you are interested in search :')
# Out:
# Enter the title of Product you are interested in search :Guitar

# %%
#seraching for the result by using relative path:
search=driver.find_element(By.XPATH,'//input[@id="nav-bb-search"]')
search.send_keys(User_input)

#click on the search button using relative path:

search_button=driver.find_element(By.XPATH,'//input[@class="nav-bb-button"]')
search_button.click()

# %% [markdown]
# # 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
#Creating the blank list for fetching the data:
Brand_Name=[]
Product_Name=[]
Price=[]
Return=[]
Expected_delivery=[]
Availability=[]
Product_URL=[]

# %%
#Getting the product URL:
Product_URL=[]
start=0
end=3
for page in range(start,end):
    url=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url:
        Product_URL.append(i.get_attribute('href'))
    next_button=driver.find_elements(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[1]/div/span[1]/div[1]/div[67]/div/div/span/a[3]')

# %%
len(Product_URL)
# Out:
# 180

# %%
#fetching the data:

for i in Product_URL:
    driver.get(i)
    time.sleep(5)
    try:
        brand_name=driver.find_element(By.XPATH,'//a[@id="bylineInfo"]')
        Brand_Name.append(brand_name.text)
    except NoSuchElementException:
        Brand_Name.append('-')
        
    time.sleep(1)
    
    try:
        product_name=driver.find_element(By.XPATH,'//span[@id="productTitle"]')
        Product_Name.append(product_name.text)
    except NoSuchElementException:
        Product_Name.append('-')
        
    time.sleep(1)
    
    try:
        price=driver.find_element(By.XPATH,'//span[@class="a-price aok-align-center"]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')
    time.sleep(1)
    try:
        returns=driver.find_element(By.XPATH,'//h2[@class="a-size-medium return-policy-title"]/span')
        Return.append(returns.text)
    except NoSuchElementException:
        Return.append('-')
    time.sleep(1)
    
    try:
        availability=driver.find_element(By.XPATH,'//div[@class="a-section a-spacing-none a-spacing-top-micro }"]/span')
        Availability.append(availability.text)
    except NoSuchElementException:
        Availability.append('-')
        
    time.sleep(1)

# %%
#length for the list:
print(len(Brand_Name),len(Product_Name),len(Price),len(Return),len(Availability))
# Out:
# 180 180 180 180 180

# %%
#Creating the data frame:

Products=pd.DataFrame({"Brand Name":Brand_Name,"Product Name":Product_Name,'Price':Price,'Availability':Availability})
Products
# Out:
#                   Brand Name  \
# 0    Visit the Kadence Store
# 1    Visit the Kadence Store
# 2    Visit the Kadence Store
# 3                Brand: enya
# 4     Visit the JUAREZ Store
# ..                       ...
# 175   Visit the Intern Store
# 176    Visit the VAULT Store
# 177           Brand: Generic
# 178      Brand: allmusicmart
# 179  Visit the MUSTANG Store
#
#                                           Product Name        Price  \
# 0    Kadence rosewood Guitar Frontier Series, Elect...   ₹4,275\n00
# 1    Kadence Frontier guitar with Online Guitar lea...   ₹3,960\n00
# 2    Kadence Slowhand Premium Jumbo Semi Acoustic G...   ₹7,999\n00
# 3    Enya Nova Go Carbon Fiber Acoustic Guitar 1/2 ...  ₹20,000\n00
# 4    Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...   ₹1,899\n00
# ..                                                 ...          ...
# 175  Intern INT-38C-VT-G 38 Incheses Cutaway Right ...   ₹2,399\n00
# ...

# %% [markdown]
# # 3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
#connecting to the webdriver chrome:
driver=webdriver.Chrome()
driver.get('https://images.google.com')

# %%
#search for the fruits using the absolute xapth:

search12=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea')
search12.send_keys('Fruits')

# click on button using the xpath:

button=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
button.click()

# %%
#Find the URL:

URL=[]
images= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            URL.append(source)

# %%
len(URL)
# Out:
# 109

# %%
import requests

# %%
#Scrapping the images:

images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
for i in range(len(img_urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])

# %%
#connecting to the webdriver:
driver=webdriver.Chrome()
driver.get('https://images.google.com')

# %%
#search for the cars using the xpath:

search12=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea')
search12.send_keys('Cars')

#click on the button using path:
button=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
button.click()

# %%
#Finding the URL:
URL=[]
images= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source= image.get_attribute('src')
    URL.append(source)

# %%
len(URL)
# Out:
# 48

# %%
#scrappping the images:

images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
for i in range(len(img_urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])

# %%
#connecting to the webdriver chrome:

driver=webdriver.Chrome()
driver.get('https://images.google.com')

# %%
#search for the guitar using the xpath:

search12=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea')
search12.send_keys('Guitar')


#click on the button using the xpath:
button=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
button.click()

# %%
#Finding the URL:

URL=[]
images= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source= image.get_attribute('src')
    URL.append(source)

# %%
#Scrapping the images:

images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
for i in range(len(img_urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])

# %%
#Connecting to the webdriver chrome:

driver=webdriver.Chrome()
driver.get('https://images.google.com')

# %%
#searching for the cakes using xpath:

search12=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea')
search12.send_keys('Cakes')


#click on the search button using xpath:

button=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
button.click()

# %%
#Getting the URL:

URL=[]
images= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source= image.get_attribute('src')
    URL.append(source)

# %%
#Scrapping for the images:

images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
for i in range(len(img_urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])

# %%
#Connecting to the webdriver chrome:

driver=webdriver.Chrome()
driver.get('https://images.google.com')

# %%
#Searching for the machine learning by xpath:

search12=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea')
search12.send_keys('Machine learning')

#click on search button using xpath:
button=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
button.click()

# %%
#scrapping the URL:
URL=[]
images= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source= image.get_attribute('src')
    URL.append(source)

# %%
#scrapping for the images:

images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
for i in range(len(img_urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
#Connecting to the webdriver chrome:

driver=webdriver.Chrome()
time.sleep(2)

#Getting the URL:
url='https://www.flipkart.com/'
driver.get(url)
time.sleep(2)

# %%
#search for iphone using the xpath:

search=driver.find_element(By.XPATH,'//input[@class="Pke_EE"]')
search.send_keys("Iphone mobile")

#click on the search button using xpath:

search_button=driver.find_element(By.XPATH,'//button[@class="_2iLD__"]')
search_button.click()

# %%
#creating the blank list for appending the data:

Product_URL=[]
Brand_Name=[]
Smartphone_Name=[]
Colour=[]
ROM=[]
Primary_camera=[]
Secondary_camera=[]
Display_size=[]
Battery_capacity=[]
Connectivity=[]

# %%
#Finding the URLs:

Product_URL=[]
product_url=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in product_url:
    href=i.get_attribute('href')
    Product_URL.append(href)

# %%
len(Product_URL)
# Out:
# 24

# %%
#fetching the data:

for i in Product_URL:
    driver.get(i)
    time.sleep(5)

#getting xpath for the readmore specification:    
    try:
        readmore=driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')
        readmore.click()
    except NoSuchElementException:
        print("Readmore")
        
    time.sleep(1)
    
    try:
        brand=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        Brand_Name.append(brand.text)
    except NoSuchElementException:
        Brand_Name.append('-')
        
    time.sleep(1)
    
    try:
        smartphone=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')
        Smartphone_Name.append(smartphone.text)
    except NoSuchElementException:
        Smartphone_Name.append('-')
        
    time.sleep(1)
    
    try:
        colour=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')
        Colour.append(colour.text)
    except NoSuchElementException:
        Colour.append('-')
    time.sleep(1)
    
    try:
        primarycamera=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[2]/td[2]/ul/li')
        Primary_camera.append(primarycamera.text)
    except NoSuchElementException:
        Primary_camera.append('-')
    time.sleep(1)
    
    try:
        secondarycamera=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[6]/td[2]/ul/li')
        Secondary_camera.append(secondarycamera.text)
    except NoSuchElementException:
        Secondary_camera.append('-')
    time.sleep(1)
    
    try:
        display=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table/tbody/tr[1]/td[2]/ul/li')
        Display_size.append(display.text)
    except NoSuchElementException:
        Display_size.append('-')
        
    time.sleep(1)
    
    try:
        battery=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/table/tbody/tr[1]/td[2]/ul/li')
        Battery_capacity.append(battery.text)
    except NoSuchElementException:
        Battery_capacity.append('')
        
    time.sleep(1)
    
    try:
        price=driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')
        
    time.sleep(1)

    try:
        rom=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr/td[2]/ul/li')
        ROM.append(rom.text)
    except NoSuchElementException:
        ROM.append('-')

# %%
print(len(Brand_Name),len(Smartphone_Name),len(Colour),len(Primary_camera),len(Secondary_camera),len(Display_size),len(Battery_capacity),len(Price))
# Out:
# 24 24 24 24 24 24 24 24

# %%
Phone=pd.DataFrame({"Brand":Brand_Name[:25],"Smartphone":Smartphone_Name[:25],"Color":Colour,"Primary Camera":Primary_camera,"Secondary Camera":Secondary_camera,"Display size":Display_size,"Battery Capacity":Battery_capacity,"Price":Price})
Phone
# Out:
#                                        Brand      Smartphone         Color  \
# 0             APPLE iPhone 14 (Blue, 128 GB)       iPhone 14          Blue
# 1        APPLE iPhone 14 (Starlight, 128 GB)       iPhone 14     Starlight
# 2         APPLE iPhone 14 (Midnight, 128 GB)       iPhone 14      Midnight
# 3        APPLE iPhone 14 Plus (Blue, 128 GB)  iPhone 14 Plus          Blue
# 4           APPLE iPhone 14 (Purple, 128 GB)       iPhone 14        Purple
# 5   APPLE iPhone 14 Plus (Starlight, 128 GB)  iPhone 14 Plus     Starlight
# 6    APPLE iPhone 14 Plus (Midnight, 128 GB)  iPhone 14 Plus      Midnight
# 7      APPLE iPhone 14 Plus (Purple, 128 GB)  iPhone 14 Plus        Purple
# 8         APPLE iPhone 14 (Midnight, 256 GB)       iPhone 14      Midnight
# 9        APPLE iPhone 14 (Starlight, 256 GB)       iPhone 14     Starlight
# 10            APPLE iPhone 14 (Blue, 256 GB)       iPhone 14          Blue
# ...

# %% [markdown]
# # 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
#Connecting to the webdriver chrome:

driver=webdriver.Chrome()
driver.get('https://www.google.co.in/maps')

# %%
#searching for the location using the xpath:

search1=driver.find_element(By.XPATH,'//input[@id="searchboxinput"]')
search1.send_keys('Airoli')

#Click on the button using the xpath:

button=driver.find_element(By.XPATH,'//div[@class="pzfvzf"]/button')
button.click()

# %%
#Creating the URL:
current_url=driver.current_url
print('Current_url:',current_url)
# Out:
# Current_url: https://www.google.co.in/maps/place/Airoli,+Navi+Mumbai,+Maharashtra+400708/@19.159216,72.9535141,13z/data=!3m1!4b1!4m6!3m5!1s0x3be7bf523dd8b5ab:0x9de9a7f73961da61!8m2!3d19.159014!4d72.9985686!16zL20vMDQ5dHI0?entry=ttu

# %%
#longitude and latitude for the given location:

try:
    if "@" in current_url:
        location=current_url.split('@')[1].split(',*/data')[0].split(',')
        location
        print('Latitude of given Location:',location[0])
        print('Longitude of given Location:',location[1])
except:
    print('Location detail not found in url')
# Out:
# Latitude of given Location: 19.159216
# Longitude of given Location: 72.9535141

# %% [markdown]
# # 6. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
#Connecting to the webdriver chrome:

driver=webdriver.Chrome()
driver.get('https://www.digit.in/')
time.sleep(3)

# %%
#click on the button using the xpath:

button=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div/div/nav/ul/li[3]/a')
button.click()

# %%
#Top10 links using the xpath:
Top10=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div[2]/div[1]/div[3]/div[1]/h3')
Top10.click()

# %%
#click on the best laptop using the xpath:

best_laptop=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div[2]/div[1]/div[3]/div[6]/p')
best_laptop.click()

# %%
#Creating the empty list:

Laptop_name=[]
Operating_system=[]
Model_name=[]
Display_size=[]
Storage=[]
Price=[]
Product_URL=[]
Connectivity=[]
RAM=[]
Weight=[]
Dimension=[]

# %%
#Getting the product URL:

Product_URL=[]
product_url=driver.find_elements(By.XPATH,'//h3[@class="font130 mt0 mb10 mobilesblockdisplay "]/a')
for i in product_url:
    href=i.get_attribute('href')
    Product_URL.append(href)

# %%
len(Product_URL)
# Out:
# 6

# %%
for i in Product_URL:
    driver.get(i)
    time.sleep(5)
   
#fetching the laptop name using the xpath:    
    try:
        laptop=driver.find_element(By.XPATH,'//h1[@class="floatleft tabletblockdisplay pr20 "]')
        Laptop_name.append(laptop.text)
    except NoSuchElementException:
        Laptop_name.append('-')
        
    time.sleep(1)
#fetching the operating system data using the xpath:

    try:
        operating_system=driver.find_element(By.XPATH,'//div[@class="specs_details "]/ul/li[1]/div/p[2]')
        Operating_system.append(operating_system.text)
    except NoSuchElementException:
        Operating_system.append('-')
        
    time.sleep(1)
    #fetching the model name using the xpath:
    try:
        model=driver.find_element(By.XPATH,'//div[@class="specs_details "]/ul/li[2]/div/p[2]')
        Model_name.append(model.text)
    except NoSuchElementException:
        Model_name.append('-')
    time.sleep(1)

#fetching the storage using the xpath:
    
    try:
        storage=driver.find_element(By.XPATH,'//div[@class="specs_details "]/ul/li[3]/div/p[2]')
        Storage.append(storage.text)
    except NoSuchElementException:
        Storage.append('-')
    time.sleep(1)

#Fetching the display using the xpath:
    
    try:
        display=driver.find_element(By.XPATH,'//div[@class="specs_details "]/ul/li[4]/div/p[2]')
        Display_size.append(display.text)
    except NoSuchElementException:
        Display_size.append('-')
    time.sleep(1)

#fetching the connectivity using the xpath:
    try:
        connectivity=driver.find_element(By.XPATH,'//table[@class="woocommerce-group-attributes-public"]/tbody/tr[6]/td/table/tbody//td')
        Connectivity.append(connectivity.text)
    except NoSuchElementException:
        Connectivity.append('-')
        
    time.sleep(1)

#fetching the weight using xpath:    
    
    try:
        weight=driver.find_element(By.XPATH,'//table[@class="woocommerce-group-attributes-public"]/tbody/tr[10]/td/table/tbody/tr[2]//td')
        Weight.append(weight.text)
    except NoSuchElementException:
        Weight.append('-')
    time.sleep(1)

#fetching RAM using the xpath:   
    try:
        ram=driver.find_element(By.XPATH,'//table[@class="woocommerce-group-attributes-public"]/tbody/tr[8]/td/table/tbody/tr[1]//td')
        RAM.append(ram.text)
    except NoSuchElementException:
        RAM.append('-')
    time.sleep(1)

#fetching the dimension using the xpath:
    
    try:
        dimension=driver.find_element(By.XPATH,'//table[@class="woocommerce-group-attributes-public"]/tbody/tr[10]/td/table/tbody/tr[1]//td')
        Dimension.append(dimension.text)
    except NoSuchElementException:
        Dimension.append('-')
    time.sleep(1)

# %%
print(len(Laptop_name),len(Operating_system),len(Model_name),len(Display_size),len(Storage),len(Connectivity),len(RAM),len(Weight),len(Dimension))
# Out:
# 6 6 6 6 6 6 6 6 6

# %%
#creating the data frame:

Laptops=pd.DataFrame({"Laptop Name":Laptop_name,"Operating System":Operating_system,"Model Name":Model_name,"Display Size":Display_size,"Storage":Storage,"Connectivity":Connectivity,"RAM":RAM,"Weight":Weight,"Dimension":Dimension})
Laptops
# Out:
#                                          Laptop Name Operating System  \
# 0                Apple MacBook Air 2022 M2 MLY03HN/A              IOS
# 1                       Samsung Galaxy Book3 Pro 360                -
# 2               Lenovo Yoga 9i13th Gen Core I7-1360P  Windows 11 Home
# 3              Apple MacBook Pro M2 (2023-MPHK3HN/A)              Mac
# 4  Dell XPS 13 Plus D560075WIN9S 12th Gen Core I7...       Windows 11
# 5     Acer Swift X SFX16-51G 11th Gen Core I7-11390H  Windows 11 Home
#
#                          Model Name Display Size Storage      Connectivity  \
# 0                          Apple M2         13.6  512 GB  Bluetooth, Wi-Fi
# 1                                 -            -       -                 -
# 2      13th Gen Intel Core I7-1360P           14  512 GB  Bluetooth, Wi-Fi
# 3                              1 TB            -    14.2  Bluetooth, Wi-Fi
# 4  12th Gen Intel EVO Core I7-1260P         13.4    1 TB  Bluetooth, Wi-Fi
# ...

# %% [markdown]
# # 7. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
#connecting to the webdriver chrome:

driver=webdriver.Chrome()
driver.get('https://www.forbes.com/')

# %%
#click on the button using the xpath:

Button1=driver.find_element(By.XPATH,'//div[@class="_69hVhdY4"]')
Button1.click()

#click on the billionaires using the xpath:
Billionaires=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div[1]/div/div[2]/ul/li[2]/div[1]/a')
Billionaires.click()

#click using the xpath:
input1=driver.find_element(By.XPATH,"/html/body/div[1]/header/nav/div[1]/div[1]/div/div[2]/ul/li[2]/div[2]/div[3]/ul/li[1]/a")
input1.click()

# %%
#creating the blank list:
Rank=[]
Name=[]
Net_worth=[]
Age=[]
Citizenship=[]
Source=[]
Industry=[]

# %%
#scrapping the rank using the xpath:

rank=driver.find_elements(By.XPATH,'//div[@class="Table_rank___YBhk Table_dataCell__2QCve"]')
for i in rank:
    rank=i.text
    Rank.append(rank)

# %%
#scrapping the name using the xpath:

name=driver.find_elements(By.XPATH,'//div[2][@class="TableRow_cell__db-hv Table_cell__houv9"]')
for i in name:
    name=i.text
    Name.append(name)

# %%
#scrapping the networth using the xpath:

networth=driver.find_elements(By.XPATH,'//div[@class="Table_netWorth___L4R5 Table_dataCell__2QCve"]')
for i in networth:
    networth=i.text
    Net_worth.append(networth)

# %%
#scrapping the age using the xpath:

age=driver.find_elements(By.XPATH,'//div[4][@class="TableRow_cell__db-hv Table_cell__houv9"]')
for i in age:
    age=i.text
    Age.append(age)

# %%
#scrapping the citizen using the xpath:

citizen=driver.find_elements(By.XPATH,'//div[5][@class="TableRow_cell__db-hv Table_cell__houv9"]')
for i in citizen:
    citizen=i.text
    Citizenship.append(citizen)

# %%
#scrapping the source using the xpath:

source=driver.find_elements(By.XPATH,'//div[6][@class="TableRow_cell__db-hv Table_cell__houv9"]')
for i in source:
    source=i.text
    Source.append(source)

# %%
#scrapping the industry using the xpath:

industry=driver.find_elements(By.XPATH,'//div[7][@class="TableRow_cell__db-hv Table_cell__houv9"]')
for i in industry:
    industry=i.text
    Industry.append(industry)

# %%
print(len(Rank),len(Name),len(Net_worth),len(Age),len(Citizenship),len(Source),len(Industry))
# Out:
# 200 200 200 200 200 200 200

# %%
#creating the data frame:

Billionaires=pd.DataFrame({"Rank":Rank,"Name":Name,"Net worth":Net_worth,"Age":Age,"Citizenship":Citizenship,"Source":Source,"Industry":Industry})
Billionaires
# Out:
#     Rank                      Name Net worth Age    Citizenship  \
# 0      1  Bernard Arnault & family    $211 B  74         France
# 1      2                 Elon Musk    $180 B  51  United States
# 2      3                Jeff Bezos    $114 B  59  United States
# 3      4             Larry Ellison    $107 B  78  United States
# 4      5            Warren Buffett    $106 B  92  United States
# ..   ...                       ...       ...  ..            ...
# 195  195               Jin Baofang    $9.6 B  70          China
# 196  195        Luo Liguo & family    $9.6 B  67          China
# 197  195              Marijke Mars    $9.6 B  58  United States
# 198  195               Pamela Mars    $9.6 B  62  United States
# 199  195              Valerie Mars    $9.6 B  64  United States
#
#                  Source               Industry
# 0                  LVMH       Fashion & Retail
# 1         Tesla, SpaceX             Automotive
# 2                Amazon             Technology
# ...

# %% [markdown]
# # 8. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
#connecting to web driver:

driver=webdriver.Chrome()
driver.get('https://www.youtube.com/')

# %%
driver=webdriver.Chrome()
driver.get('https://www.youtube.com/')

#Clicking on the search using xpath:
search1=driver.find_element(By.XPATH,'//input[@id="search"]')
search1.send_keys('Sadhguru: Journey of a Fake Spiritual Guru')

#clicking on the button using the xpath:
button=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/div/ytd-masthead/div[4]/div[2]/ytd-searchbox/button/yt-icon/yt-icon-shape/icon-shape')
button.click()

# %%
#video link using xpath:
video_link=driver.find_element(By.XPATH,'//yt-formatted-string[@class="style-scope ytd-video-renderer"]')
video_link.click()

# %%
#creating empty list 
Comments=[]
Comments_ago=[]
Comment_posted=[]
Likes=[]
No_of_Likes=[]

# %%
#scrapping comments using the xpath:

comment=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="style-scope ytd-comment-renderer"]')
time.sleep(3)
for i in comment:
    if i.text is None:
        Comments.append('--')
    else:
        Comments.append(i.text)
time.sleep(2)

# %%
len(Comments)
# Out:
# 540

# %%
#scrapping the timeline for comments using xpath:

timeline=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="published-time-text style-scope ytd-comment-renderer"]/a')
time.sleep(3)
for i in timeline:
    if i.text is None:
        Comments_ago.append('--')
    else:
        Comments_ago.append(i.text)

# %%
len(Comments_ago)
# Out:
# 540

# %%
#scrapping the no of likes using the xpath:

like=driver.find_elements(By.XPATH,'//span[@class="style-scope ytd-comment-action-buttons-renderer"]')
for i in like:
    Likes.append(i.text)
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])
time.sleep(3)

# %%
len(No_of_Likes)
# Out:
# 1080

# %%
#Creating the data frame:

Youtube=pd.DataFrame({"Comments":Comments[:500],"Comment Posted Ago":Comments_ago[:500],"No.of Likes":No_of_Likes[:500]})
Youtube
# Out:
#                                               Comments     Comment Posted Ago  \
# 0    This is just out of the world, i never thought...           8 months ago
# 1    As long as people keep looking for solutions o...  17 hours ago (edited)
# 2    He is an intelligent man living on utilising o...              1 day ago
# 3               Absolute masterpiece of a documentary!              1 day ago
# 4    This should be presented as NETFLIX documentar...             9 days ago
# ..                                                 ...                    ...
# 495  You know what, I joined an Ashram 5 years befo...           16 hours ago
# 496                               You are doing great.             2 days ago
# 497                                          Great job           10 hours ago
# 498  Good job   1 year ago I felt something fishy a...           7 months ago
# 499                                     Ankhe khol di               1 day ago
#
#     No.of Likes
# ...

# %% [markdown]
# # 9. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
#Connecting to the web driver:
driver=webdriver.Chrome()
driver.get('https://www.hostelworld.com/')

# %%
#Entering the input using xpath:
location=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div[2]/div/div/div[2]/div/div[1]/div/div[1]/div/div/div[2]/input')
location.send_keys('London')

# %%
#click on the button using xpath:

button=driver.find_element(By.XPATH,'//div[@class="destination-search-results select-list-container"]/ul/li[2]')
button.click()

# %%
#click on second button using the xpath:

button2=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div[2]/div/div/div[3]/div/div/button[2]')
button2.click()

# %%
#click on lets go using xpath:

letsgo=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div[2]/div/div/div[3]/div/div/button')
letsgo.click()

# %%
#Creating the empty list:
Hostel_name=[]
Distance=[]
Ratings=[]
Total_reviews=[]
Overall_reviews=[]
Private_price=[]
Dorm_price=[]
Facilities=[]
Property_description=[]
product_url=[]

# %%
#URL for the pages:
product_url=[]
url=driver.find_elements(By.XPATH,'//div[@class="property-card"]//a//a')
for i in url:
    href=i.get_attribute('href')
    product_url.append(href)

# %%
len(product_url)
# Out:
# 32

# %%
#Fetching the data for empty list:
for i in product_url:
    driver.get(i)
    time.sleep(5)
    
    try:
        hostel_name=driver.find_element(By.XPATH,'//div[@class="title-2"]')
        Hostel_name.append(hostel_name.text)
    except NoSuchElementException:
        Hostel_name.append('-')
        
    time.sleep(1)
    
    try:
        distance=driver.find_element(By.XPATH,'//div[@class="property-distance"]//span[2]')
        Distance.append(distance.text)
    except NoSuchElementException:
        Distance.append('-')
        
    time.sleep(1)
    
    try:
        rat=driver.find_element(By.XPATH,'//div[@class="flex-20"]/div[1]/div[1]')
        Ratings.append(rat.text)
    except NoSuchElementException:
        Ratings.append('-')
    time.sleep(1)
    
    try:
        total=driver.find_element(By.XPATH,'//div[@class="flex-20"]/div[1]/div[2]/div[2]')
        Total_reviews.append(total.text)
    except NoSuchElementException:
        Total_reviews.append('-')
    time.sleep(1)
    
    try:
        overall=driver.find_element(By.XPATH,'//div[@class="flex-20"]/div[1]/div[2]/div/span')
        Overall_reviews.append(overall.text)
    except NoSuchElementException:
        Overall_reviews.append('-')
    time.sleep(1)
    
    try:
        fac1 = driver.find_elements(By.XPATH,'//div[@id="facilities-section"]//div//ul//li[1]//ul[1]//li[2]')
        fac2 = driver.find_elements(By.XPATH,'//div[@id="facilities-section"]//div//ul//li[2]//ul[1]//li[17]')
        for i in fac1:
            for j in fac2:
                Facilities.append(i.text +', '+ j.text )
    except NoSuchElementException:
        Facilities.append('-')
    time.sleep(1)
    
    try:
        desc=driver.find_element(By.XPATH,'//div[@class="flex-80"]//div[4]')
        Property_description.append(desc.text)
    except NoSuchElementException:
        Property_description.append('-')
    time.sleep(1)
    
    try:
    private=driver.find_element(By.XPATH,'//div[5][@data-v-c308b52c]/div/div[1]/div[2]/strong[1]')
    if dorm:
        Private_price.append(private.text)
    else:
        Private_price.append('-')
except NoSuchElementException:
    Private_price.append('-')
time.sleep(1)

# %%
#Getting data for the distance using xpath:
try:
    dist1 = driver.find_elements(By.XPATH, '//div[3][@data-v-c308b52c]//span[2]')
    if dist1:
        Distance.append(dist1[10].text)
    else:
        Distance.append('-')
except NoSuchElementException:
    Distance.append('-')

# %%
len(Distance)
# Out:
# 10

# %%
#Getting the private price using xpath:
try:
    private=driver.find_element(By.XPATH,'//div[5][@data-v-c308b52c]/div/div[1]/div[2]/strong[1]')
    if dorm:
        Private_price.append(private.text)
    else:
        Private_price.append('-')
except NoSuchElementException:
    Private_price.append('-')
time.sleep(1)

# %%
len(Private_price)
# Out:
# 10

# %%
dt2=pd.DataFrame({"pri":Private_price})
dt2
# Out:
#        pri
# 0  ₹15,107
# 1  ₹15,107
# 2  ₹15,107
# 3  ₹15,107
# 4  ₹15,107
# 5  ₹15,107
# 6  ₹15,107
# 7  ₹15,107
# 8  ₹15,107
# 9  ₹15,107

# %%
#Getting dorm price using xpath:
try:
    dorm_price=driver.find_element(By.XPATH,'//div[@data-v-6952bb44]//div[2]//div[2]//div[2]//div[3]//div[2]')
    if dorm_price:
        Dorm_price.append(dorm_price.text)
    else:
        Dorm_price.append('-')
except NoSuchElementException:
    Dorm_price.append('-')
time.sleep(1)

# %%
len(Dorm_price)
# Out:
# 10

# %%
import pandas as pd

# %%
print(len(Hostel_name),len(Ratings),len(Total_reviews),len(Overall_reviews),len(Facilities),len(Property_description))
# Out:
# 32 32 32 32 13 32

# %%
#Creating the data frame:

Hotels=pd.DataFrame({"Hostel Name":Hostel_name[:10],"Ratings":Ratings[:10],"Total Reviews":Total_reviews[:10],"Overall Reviews":Overall_reviews[:10],"Facilities":Facilities[:10],"Property Description":Property_description[:10]})
Hotels
# Out:
#                          Hostel Name Ratings        Total Reviews  \
# 0           St Christopher's Village     8.2  12623 Total Reviews
# 1      Palmers Lodge - Swiss Cottage     8.8  15811 Total Reviews
# 2        Wombat's City Hostel London     9.0  15562 Total Reviews
# 3           St Christopher's Village     8.2  12623 Total Reviews
# 4                Onefam Notting Hill     9.6   2382 Total Reviews
# 5               Urbany Hostel London     9.5   1008 Total Reviews
# 6      Palmers Lodge - Swiss Cottage     8.8  15811 Total Reviews
# 7                   Generator London     7.5   7911 Total Reviews
# 8  Safestay London Elephant & Castle     7.1   5185 Total Reviews
# 9                   NX London Hostel     8.3   2037 Total Reviews
#
#   Overall Reviews                                         Facilities  \
# 0        Fabulous    Free WiFi, Follows Covid-19 sanitation guidance
# 1        Fabulous                           Free WiFi, Reading Light
# ...

# %%
#Adding Distance as column to the hotel data frame:
Hotels["Distance"]=Distance
print(Hotels)
# Out:
#                          Hostel Name Ratings        Total Reviews  \
# 0           St Christopher's Village     8.2  12623 Total Reviews
# 1      Palmers Lodge - Swiss Cottage     8.8  15811 Total Reviews
# 2        Wombat's City Hostel London     9.0  15562 Total Reviews
# 3           St Christopher's Village     8.2  12623 Total Reviews
# 4                Onefam Notting Hill     9.6   2382 Total Reviews
# 5               Urbany Hostel London     9.5   1008 Total Reviews
# 6      Palmers Lodge - Swiss Cottage     8.8  15811 Total Reviews
# 7                   Generator London     7.5   7911 Total Reviews
# 8  Safestay London Elephant & Castle     7.1   5185 Total Reviews
# 9                   NX London Hostel     8.3   2037 Total Reviews
#
#   Overall Reviews                                         Facilities  \
# 0        Fabulous    Free WiFi, Follows Covid-19 sanitation guidance
# 1        Fabulous                           Free WiFi, Reading Light
# ...

# %%
#Adding private price as column to data frame:
Hotels["PrivatePrice"]=Private_price
print(Hotels)
# Out:
#                          Hostel Name Ratings        Total Reviews  \
# 0           St Christopher's Village     8.2  12623 Total Reviews
# 1      Palmers Lodge - Swiss Cottage     8.8  15811 Total Reviews
# 2        Wombat's City Hostel London     9.0  15562 Total Reviews
# 3           St Christopher's Village     8.2  12623 Total Reviews
# 4                Onefam Notting Hill     9.6   2382 Total Reviews
# 5               Urbany Hostel London     9.5   1008 Total Reviews
# 6      Palmers Lodge - Swiss Cottage     8.8  15811 Total Reviews
# 7                   Generator London     7.5   7911 Total Reviews
# 8  Safestay London Elephant & Castle     7.1   5185 Total Reviews
# 9                   NX London Hostel     8.3   2037 Total Reviews
#
#   Overall Reviews                                         Facilities  \
# 0        Fabulous    Free WiFi, Follows Covid-19 sanitation guidance
# 1        Fabulous                           Free WiFi, Reading Light
# ...

# %%
#Adding the Dorm price as column to data frame:
Hotels['Dorm Price']=Dorm_price
print(Hotels)
# Out:
#                          Hostel Name Ratings        Total Reviews  \
# 0           St Christopher's Village     8.2  12623 Total Reviews
# 1      Palmers Lodge - Swiss Cottage     8.8  15811 Total Reviews
# 2        Wombat's City Hostel London     9.0  15562 Total Reviews
# 3           St Christopher's Village     8.2  12623 Total Reviews
# 4                Onefam Notting Hill     9.6   2382 Total Reviews
# 5               Urbany Hostel London     9.5   1008 Total Reviews
# 6      Palmers Lodge - Swiss Cottage     8.8  15811 Total Reviews
# 7                   Generator London     7.5   7911 Total Reviews
# 8  Safestay London Elephant & Castle     7.1   5185 Total Reviews
# 9                   NX London Hostel     8.3   2037 Total Reviews
#
#   Overall Reviews                                         Facilities  \
# 0        Fabulous    Free WiFi, Follows Covid-19 sanitation guidance
# 1        Fabulous                           Free WiFi, Reading Light
# ...

# %%
#Final data frame:

Hotels
# Out:
#                          Hostel Name Ratings        Total Reviews  \
# 0           St Christopher's Village     8.2  12623 Total Reviews
# 1      Palmers Lodge - Swiss Cottage     8.8  15811 Total Reviews
# 2        Wombat's City Hostel London     9.0  15562 Total Reviews
# 3           St Christopher's Village     8.2  12623 Total Reviews
# 4                Onefam Notting Hill     9.6   2382 Total Reviews
# 5               Urbany Hostel London     9.5   1008 Total Reviews
# 6      Palmers Lodge - Swiss Cottage     8.8  15811 Total Reviews
# 7                   Generator London     7.5   7911 Total Reviews
# 8  Safestay London Elephant & Castle     7.1   5185 Total Reviews
# 9                   NX London Hostel     8.3   2037 Total Reviews
#
#   Overall Reviews                                         Facilities  \
# 0        Fabulous    Free WiFi, Follows Covid-19 sanitation guidance
# 1        Fabulous                           Free WiFi, Reading Light
# ...
